# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import openrouteservice as ors
import requests

# %%
API_KEY = '5b3ce3597851110001cf62484364c6151eb540e3949acae6888d47ef'

client = ors.Client(key=API_KEY)

# %% [markdown]
# ## Visualizing bus routes

# %%
bus_stops = pd.read_csv('bus_stop_coords.csv', header=None)
bus_stops.rename(columns={0:"Bus Stop", 1:"lat", 2:"lon"}, inplace=True)
bus_stops
# Out:
#                         Bus Stop       lat         lon
# 0                          UTown  1.303555  103.774414
# 1                         Museum  1.301081  103.773694
# 2                            UHC  1.298913  103.776112
# 3                        Opp UHC  1.298789  103.775627
# 4                        Opp YIH  1.298973  103.774179
# 5                            YIH  1.298898  103.774388
# 6                             IT  1.297234  103.772697
# 7                            CLB  1.296365  103.772261
# 8                         Ventus  1.295335  103.770531
# 9                           LT13  1.294727  103.770627
# 10                      Opp NUSS  1.293395  103.771905
# 11                           AS5  1.293502  103.771859
# 12                          BIZ2  1.293238  103.775127
# 13                     Opp HSSML  1.292963  103.775118
# 14                          COM3  1.294962  103.774965
# 15                     Opp TCOMS  1.293711  103.777007
# 16                         TCOMS  1.293597  103.777066
# 17                  PGP Terminal  1.291845  103.780436
# 18                     PGP Foyer  1.291019  103.781156
# 19                        KR MRT  1.294803  103.784398
# 20                    Opp KR MRT  1.295020  103.784567
# 21                          LT27  1.297352  103.780952
# 22                           S17  1.297523  103.780730
# 23               University Hall  1.297131  103.778796
# 24           Opp University Hall  1.297521  103.778127
# 25               KR Bus Terminal  1.294150  103.769168
# 26                  Raffles Hall  1.300977  103.772702
# 27                     Kent Vale  1.301961  103.769476
# 28                            EA  1.300601  103.770173
# 29                          SDE3  1.297816  103.769936
# 30                      Opp SDE3  1.297832  103.769587
# 31   The Japanese Primary School  1.300763  103.769932
# 32     Botanic Gardens MRT (BTC)  1.322733  103.815165
# 33           College Green (BTC)  1.323395  103.816267
# 34  Oei Tiong Ham Building (BTC)  1.319830  103.817759

# %% [markdown]
# ### All bus stops

# %%
map = folium.Map(location = [1.3083003040174188, 103.79569430095988], zoom_start = 15)
for i in range(len(bus_stops)):
    folium.Marker(location=[bus_stops.iloc[i, 1], bus_stops.iloc[i, 2]], popup=bus_stops.iloc[i, 0]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fb1c2da507cd8ae96497c229807b245 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fb1c2da507cd8ae96497c229807b245&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fb1c2da507cd8ae96497c229807b245 = L.map(
#                 &quot;map_0fb1c2da507cd8ae96497c229807b245&quot;,
#                 {
#                     center: [1.3083003040174188, 103.79569430095988],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a3ba019ffa01c28d7ccc988dd79bdf62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a3ba019ffa01c28d7ccc988dd79bdf62.addTo(map_0fb1c2da507cd8ae96497c229807b245);
#
#
#             var marker_110688ffec9e701dcef6d43a661d25cf = L.marker(
#                 [1.3035546593332374, 103.77441438310554],
#                 {}
#             ).addTo(map_0fb1c2da507cd8ae96497c229807b245);
#
#
#         var popup_6e3ba2d0207030fe4bd460008d9717fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_377a55b0410d09afe8e1c28269bf4cb1 = $(`&lt;div id=&quot;html_377a55b0410d09afe8e1c28269bf4cb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTown&lt;/div&gt;`)[0];
#                 popup_6e3ba2d0207030fe4bd460008d9717fb.setContent(html_377a55b0410d09afe8e1c28269bf4cb1);
#
#
#
#         marker_110688ffec9e701dcef6d43a661d25cf.bindPopup(popup_6e3ba2d0207030fe4bd460008d9717fb)
#         ;
#
#
#
#
#             var marker_dff9aa1430f1a4c24dccc9cc90857b15 = L.marker(
#                 [1.3010811364904713, 103.77369406623278],
#                 {}
#             ).addTo(map_0fb1c2da507cd8ae96497c229807b245);
#
#
#         var popup_b119efd135c61888cb3f0a243b75420c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4207ebbda712582355e2bcf9fc7d31a8 = $(`&lt;div id=&quot;html_4207ebbda712582355e2bcf9fc7d31a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Museum&lt;/div&gt;`)[0];
#                 popup_b119efd135c61888cb3f0a243b75420c.setContent(html_4207ebbda712582355e2bcf9fc7d31a8);
#
#
#
#         marker_dff9aa1430f1a4c24dccc9cc90857b15.bindPopup(popup_b119efd135c61888cb3f0a243b75420c)
#         ;
#
#
#
#
#             var marker_e6127bbee67982ff7027a9bc61be0c5e = L.marker(
#                 [1.2989132429412726, 103.77611186756018],
#                 {}
#             ).addTo(map_0fb1c2da507cd8ae96497c229807b245);
#
#
#         var popup_9d21b0de40bb2f5ea1a079a70cad276a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9ec801f3af4f497883fe66758a975ede = $(`&lt;div id=&quot;html_9ec801f3af4f497883fe66758a975ede&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UHC&lt;/div&gt;`)[0];
#                 popup_9d21b0de40bb2f5ea1a079a70cad276a.setContent(html_9ec801f3af4f497883fe66758a975ede);
#
#
#
#         marker_e6127bbee67982ff7027a9bc61be0c5e.bindPopup(popup_9d21b0de40bb2f5ea1a079a70cad276a)
#         ;
#
#
#
#
#             var marker_d55a8a3c446bccafea9ac982640f0fe3 = L.marker(
#                 [1.2987886001367377, 103.775626526238],
#                 {}
#             ).addTo(map_0fb1c2da507cd8ae96497c229807b245);
#
#
#         var popup_96022cd7cc7c4486cead37549ff8cd60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b34294a221b113f3420c6b4b7078479 = $(`&lt;div id=&quot;html_7b34294a221b113f3420c6b4b7078479&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Opp UHC&lt;/div&gt;`)[0];
#                 popup_96022cd7cc7c4486cead37549ff8cd60.setContent(html_7b34294a221b113f3420c6b4b7078479);
#
#
#
#         marker_d55a8a3c446bccafea9ac982640f0fe3.bindPopup(popup_96022cd7cc7c4486cead37549ff8cd60)
#         ;
#
#
#
#
#             var marker_bd926c0e472b3e1fcfd0fd911d7a2599 = L.marker(
#                 [1.2989725099505092, 103.77417867705664],
#                 {}
#             ).addTo(map_0fb1c2da507cd8ae96497c229807b245);
#
#
#         var popup_dcb19dd7faf127abc8457a0d0ce5bbf8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab609e59c3d879a6615e09bbd40b8ab5 = $(`&lt;div id=&quot;html_ab609e59c3d879a6615e09bbd40b8ab5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Opp YIH&lt;/div&gt;`)[0];
#                 popup_dcb19dd7faf127abc8457a0d0ce5bbf8.setContent(html_ab609e59c3d879a6615e09bbd40b8ab5);
#
#
#
#         marker_bd926c0e472b3e1fcfd0fd911d7a2599.bindPopup(popup_dcb19dd7faf127abc8457a0d0ce5bbf8)
#         ;
#
#
#
#
#             var marker_7db54acba7fdbe2d5dcb0e69af1eaca4 = L.marker(
#                 [1.2988982413553634, 103.7743884

# %% [markdown]
# ### A1 route

# %% [markdown]
# #### Operating hours
# | Term | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0715 | 2300 |
# | Sun/PH | 0900 | 2300 |

# %% [markdown]
# | Vacation | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0715 | 2300 |
# | Sun/PH | 0900 | 2300 |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday |  | Sun/PH |  |
# | --- | --- | --- | --- | --- | --- |
# | 0715 - 0800 | 8-10 min | 0715 - 1930 | 15 min | 0900 - 2300 | 30 min |
# | 0801 - 1000 | 4-6 min | 1931 - 2300 | 30 min | | |
# | 1001 - 1100 | 10-12 min | | | | |
# | 1101 - 1400 | 5-7 min | | | | |
# | 1401 - 1715 | 8-10 min | | | | |
# | 1716 - 1930 | 5-7 min | | | | |
# | 1931 - 2300 | 15 min | | | | |

# %%
A1_bus = ['KR Bus Terminal', 'LT13', 'AS5', 'BIZ2', 'Opp TCOMS', 'PGP Terminal', 'KR MRT', 'LT27', 
          'University Hall', 'Opp UHC', 'YIH', 'CLB', 'KR Bus Terminal']

A1_stops = bus_stops[bus_stops['Bus Stop'].isin(A1_bus)]
A1_route_df = pd.DataFrame({'Bus Stop': A1_bus})
A1_route_df['route_index'] = A1_route_df.index

A1 = A1_route_df.merge(A1_stops, on='Bus Stop', how='left')
A1.loc[A1['route_index']==0, 'color'] = 'red'
A1.loc[A1['route_index']!=0, 'color'] = 'blue'
A1.loc[A1['route_index']==A1.shape[0]-1, 'color'] = 'red'
A1.drop(columns='route_index', inplace=True)


map = folium.Map(location = [1.2993920113270834, 103.77841451795645], zoom_start = 16)
for i in range(len(A1)):
    folium.Marker(location=[A1.iloc[i, 1], A1.iloc[i, 2]], icon=folium.Icon(color=A1.iloc[i, 3]), popup=A1.iloc[i, 0]).add_to(map)

dir_coord = [(A1.iloc[i,2], A1.iloc[i,1]) for i in range(len(A1))]
route = client.directions(coordinates=dir_coord, profile='driving-car', format='geojson', optimize_waypoints=True)
route_coords = [list(reversed(coord)) for coord in route['features'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9db5af8083afe1687bb96ceeb77e1d46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9db5af8083afe1687bb96ceeb77e1d46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9db5af8083afe1687bb96ceeb77e1d46 = L.map(
#                 &quot;map_9db5af8083afe1687bb96ceeb77e1d46&quot;,
#                 {
#                     center: [1.2993920113270834, 103.77841451795645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45ccec352de5c60cc946a7301b88e706 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_45ccec352de5c60cc946a7301b88e706.addTo(map_9db5af8083afe1687bb96ceeb77e1d46);
#
#
#             var marker_9cf96b868f9df298d896e7b255a4c2b7 = L.marker(
#                 [1.29415, 103.769168],
#                 {}
#             ).addTo(map_9db5af8083afe1687bb96ceeb77e1d46);
#
#
#             var icon_c3bf0363fa426cf115234f32e57221cb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9cf96b868f9df298d896e7b255a4c2b7.setIcon(icon_c3bf0363fa426cf115234f32e57221cb);
#
#
#         var popup_5bb57961e0d4254273cbe4add1ed8cdf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0b953fde5b8663cbc4b185e2c6e3721 = $(`&lt;div id=&quot;html_b0b953fde5b8663cbc4b185e2c6e3721&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KR Bus Terminal&lt;/div&gt;`)[0];
#                 popup_5bb57961e0d4254273cbe4add1ed8cdf.setContent(html_b0b953fde5b8663cbc4b185e2c6e3721);
#
#
#
#         marker_9cf96b868f9df298d896e7b255a4c2b7.bindPopup(popup_5bb57961e0d4254273cbe4add1ed8cdf)
#         ;
#
#
#
#
#             var marker_93e67a1ebb1436bff489020315fede11 = L.marker(
#                 [1.2947269559634624, 103.77062733455368],
#                 {}
#             ).addTo(map_9db5af8083afe1687bb96ceeb77e1d46);
#
#
#             var icon_cc8c8749fc93902b1413da3c8242027c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_93e67a1ebb1436bff489020315fede11.setIcon(icon_cc8c8749fc93902b1413da3c8242027c);
#
#
#         var popup_5a959bdae4519f9659144cdaf7cbe1ea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b17e6b6154129e1be149d9e253f06695 = $(`&lt;div id=&quot;html_b17e6b6154129e1be149d9e253f06695&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LT13&lt;/div&gt;`)[0];
#                 popup_5a959bdae4519f9659144cdaf7cbe1ea.setContent(html_b17e6b6154129e1be149d9e253f06695);
#
#
#
#         marker_93e67a1ebb1436bff489020315fede11.bindPopup(popup_5a959bdae4519f9659144cdaf7cbe1ea)
#         ;
#
#
#
#
#             var marker_2537a3797fbbbcb75ad1921ecd016a25 = L.marker(
#                 [1.293502262315002, 103.7718589614246],
#                 {}
#             ).addTo(map_9db5af8083afe1687bb96ceeb77e1d46);
#
#
#             var icon_d587d0a52b618f290bef5acd372c0633 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2537a3797fbbbcb75ad1921ecd016a25.setIcon(icon_d587d0a52b618f290bef5acd372c0633);
#
#
#         var popup_539cebd1d8028e283a93c04a6355a132 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_389ae90414ae5f1e2f36a89080553e17 = $(`&lt;div id=&quot;html_389ae90414ae5f1e2f36a89080553e17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AS5&lt;/div&gt;`)[0];
#                 popup_539cebd1d8028e283a93c04a6355a132.setContent(html_389ae90414ae5f1e2f36a89080553e17);
#
#
#
#         marker_2537a3797fbbbcb75ad1921ecd016a25.bindPopup(popup_539cebd1d8028e283a93c04a6355a132)
#         ;
#
#
#
#
#             var marker_cfdd1c8b24a3bc57df5f6f56d4c880c8 = L.marker(
#                 [1.293237778373149, 103.7751270971964],
#                 {}
#             ).addTo(map_9db5af8083afe1687bb96ceeb77e1d46);
#
#
#             var icon_3190bdc5552fe36be8326e38acad085d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot

# %% [markdown]
# ### A2 route

# %% [markdown]
# #### Operating hours
# | Term | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0715 | 2300 |
# | Sun/PH | 0900 | 2300 |

# %% [markdown]
# | Vacation | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0715 | 2300 |
# | Sun/PH | 0900 | 2300 |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday |  | Sun/PH |  |
# | --- | --- | --- | --- | --- | --- |
# | 0715 - 1000 | 6-8 min | 0715 - 1930 | 15 min | 0900 - 2300 | 30 min |
# | 1001 - 1115 | 9-11 min | 1931 - 2300 | 30 min | | |
# | 1116 - 1400 | 6-8 min | | | | |
# | 1401 - 1700 | 7-10 min | | | | |
# | 1701 - 1930 | 6-8 min | | | | |
# | 1931 - 2130 | 11-13 min | | | | |
# | 2131 - 2300 | 15 min | | | | |

# %%
A2_bus = ['KR Bus Terminal', 'IT', 'Opp YIH', 'Museum', 'UHC', 'Opp University Hall', 'S17', 'Opp KR MRT', 
          'PGP Foyer', 'TCOMS', 'Opp HSSML', 'Opp NUSS', 'Ventus', 'KR Bus Terminal']

A2_stops = bus_stops[bus_stops['Bus Stop'].isin(A2_bus)]
A2_route_df = pd.DataFrame({'Bus Stop': A2_bus})
A2_route_df['route_index'] = A2_route_df.index

A2 = A2_route_df.merge(A2_stops, on='Bus Stop', how='left')
A2.loc[A2['route_index']==0, 'color'] = 'red'
A2.loc[A2['route_index']!=0, 'color'] = 'blue'
A2.loc[A2['route_index']==A2.shape[0]-1, 'color'] = 'red'
A2.drop(columns='route_index', inplace=True)


map = folium.Map(location = [1.2993920113270834, 103.77841451795645], zoom_start = 16)
for i in range(len(A2)):
    folium.Marker(location=[A2.iloc[i, 1], A2.iloc[i, 2]], icon=folium.Icon(color=A2.iloc[i, 3]), popup=A2.iloc[i, 0]).add_to(map)

dir_coord = [(A2.iloc[i,2], A2.iloc[i,1]) for i in range(len(A2))]
route = client.directions(coordinates=dir_coord, profile='driving-car', format='geojson', optimize_waypoints=True)
route_coords = [list(reversed(coord)) for coord in route['features'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3c0b37a57670b343ca1d9392160cf844 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3c0b37a57670b343ca1d9392160cf844&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3c0b37a57670b343ca1d9392160cf844 = L.map(
#                 &quot;map_3c0b37a57670b343ca1d9392160cf844&quot;,
#                 {
#                     center: [1.2993920113270834, 103.77841451795645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55719c692af0c9d57aa33155b0d01bc8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_55719c692af0c9d57aa33155b0d01bc8.addTo(map_3c0b37a57670b343ca1d9392160cf844);
#
#
#             var marker_1560a344ef180345087d91883231f2ef = L.marker(
#                 [1.29415, 103.769168],
#                 {}
#             ).addTo(map_3c0b37a57670b343ca1d9392160cf844);
#
#
#             var icon_1136c6419ff68971856d7efaed4654a5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1560a344ef180345087d91883231f2ef.setIcon(icon_1136c6419ff68971856d7efaed4654a5);
#
#
#         var popup_08144fd82a0e05b1dabb1b15fcc07593 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc7c0d515044899eda20a9742ef50cfe = $(`&lt;div id=&quot;html_dc7c0d515044899eda20a9742ef50cfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KR Bus Terminal&lt;/div&gt;`)[0];
#                 popup_08144fd82a0e05b1dabb1b15fcc07593.setContent(html_dc7c0d515044899eda20a9742ef50cfe);
#
#
#
#         marker_1560a344ef180345087d91883231f2ef.bindPopup(popup_08144fd82a0e05b1dabb1b15fcc07593)
#         ;
#
#
#
#
#             var marker_3888a812698a6e718c8d6fb6dc4590e3 = L.marker(
#                 [1.297233750488144, 103.77269729320729],
#                 {}
#             ).addTo(map_3c0b37a57670b343ca1d9392160cf844);
#
#
#             var icon_d53aaf0e5aeec052dcf2f8f04ad78c80 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3888a812698a6e718c8d6fb6dc4590e3.setIcon(icon_d53aaf0e5aeec052dcf2f8f04ad78c80);
#
#
#         var popup_cd9ac1d6dc166a9b3b86b0d52d0b463c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_26b983712a435727e8cdc52fca1fc53d = $(`&lt;div id=&quot;html_26b983712a435727e8cdc52fca1fc53d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IT&lt;/div&gt;`)[0];
#                 popup_cd9ac1d6dc166a9b3b86b0d52d0b463c.setContent(html_26b983712a435727e8cdc52fca1fc53d);
#
#
#
#         marker_3888a812698a6e718c8d6fb6dc4590e3.bindPopup(popup_cd9ac1d6dc166a9b3b86b0d52d0b463c)
#         ;
#
#
#
#
#             var marker_8a5f2840969fef6c0628f7d2fb4ae1c7 = L.marker(
#                 [1.2989725099505092, 103.77417867705664],
#                 {}
#             ).addTo(map_3c0b37a57670b343ca1d9392160cf844);
#
#
#             var icon_3fa8e3c4289ce4aa3a82ff19dec9c06f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8a5f2840969fef6c0628f7d2fb4ae1c7.setIcon(icon_3fa8e3c4289ce4aa3a82ff19dec9c06f);
#
#
#         var popup_d8945ce0288ca68d09f74f897f2e2b1d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bae8680b35ab906c207867d551f686c0 = $(`&lt;div id=&quot;html_bae8680b35ab906c207867d551f686c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Opp YIH&lt;/div&gt;`)[0];
#                 popup_d8945ce0288ca68d09f74f897f2e2b1d.setContent(html_bae8680b35ab906c207867d551f686c0);
#
#
#
#         marker_8a5f2840969fef6c0628f7d2fb4ae1c7.bindPopup(popup_d8945ce0288ca68d09f74f897f2e2b1d)
#         ;
#
#
#
#
#             var marker_6a7b1881f2716666601539dadfa9bd10 = L.marker(
#                 [1.3010811364904713, 103.77369406623278],
#                 {}
#             ).addTo(map_3c0b37a57670b343ca1d9392160cf844);
#
#
#             var icon_f2c24c13a8086c43b429543478e0c1d5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign

# %% [markdown]
# ### Getting accurate route data from Mapbox API

# %%
museum_to_utown_url = 'https://api.mapbox.com/directions/v5/mapbox/driving/103.773474%2C1.301166%3B103.774422%2C1.303533?alternatives=false&geometries=geojson&language=en&overview=full&steps=true&access_token=pk.eyJ1IjoiZ3VvaG9uZ3lpMTExIiwiYSI6ImNtMng0OHc4cTAwenMybG9iczg4cjBoNjcifQ.tc6o1kU_mTemKQhbVy5mNA'
response = requests.get(museum_to_utown_url)
museum_to_utown = response.json()

utown_to_yih_url = 'https://api.mapbox.com/directions/v5/mapbox/driving/103.774422%2C1.303533%3B103.774308%2C1.298869?alternatives=false&geometries=geojson&language=en&overview=full&steps=true&access_token=pk.eyJ1IjoiZ3VvaG9uZ3lpMTExIiwiYSI6ImNtMng0OHc4cTAwenMybG9iczg4cjBoNjcifQ.tc6o1kU_mTemKQhbVy5mNA'
yih_response = requests.get(utown_to_yih_url)
utown_to_yih = yih_response.json()

utown_to_uhc_url = 'https://api.mapbox.com/directions/v5/mapbox/driving/103.774422%2C1.303533%3B103.776055%2C1.298898?alternatives=false&geometries=geojson&language=en&overview=full&steps=true&access_token=pk.eyJ1IjoiZ3VvaG9uZ3lpMTExIiwiYSI6ImNtMng0OHc4cTAwenMybG9iczg4cjBoNjcifQ.tc6o1kU_mTemKQhbVy5mNA'
uhc_response = requests.get(utown_to_uhc_url)
utown_to_uhc = uhc_response.json()

# %% [markdown]
# ### D1 route

# %% [markdown]
# #### Operating hours
# | Term | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0720 | 2300 |
# | Sun/PH | 0900 | 2300 |

# %% [markdown]
# | Vacation | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0720 | 2300 |
# | Sun/PH | 0900 | 2300 |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday |  | Sun/PH |  |
# | --- | --- | --- | --- | --- | --- |
# | 0715 - 0800 | 10-12 min | 0720 - 1930 | 15 min | 0900 - 2300 | 30 min |
# | 0801 - 1930 | 6-8 min | 1931 - 2300 | 30 min | | |
# | 1931 - 2130 | 11-13 min | | | | |
# | 2131 - 2300 | 15 min | | | | |

# %%
D1_bus = ['COM3', 'Opp HSSML', 'Opp NUSS', 'Ventus', 'IT', 'Opp YIH', 'Museum', 'UTown', 'YIH', 'CLB', 'LT13', 'AS5', 'BIZ2', 'COM3']

D1_stops = bus_stops[bus_stops['Bus Stop'].isin(D1_bus)]
D1_route_df = pd.DataFrame({'Bus Stop': D1_bus})
D1_route_df['route_index'] = D1_route_df.index

D1 = D1_route_df.merge(D1_stops, on='Bus Stop', how='left')
D1.loc[D1['route_index']==0, 'color'] = 'red'
D1.loc[D1['route_index']!=0, 'color'] = 'blue'
D1.loc[D1['route_index']==D1.shape[0]-1, 'color'] = 'red'
D1.drop(columns='route_index', inplace=True)


map = folium.Map(location = [1.2993920113270834, 103.77841451795645], zoom_start = 16)
for i in range(len(D1)):
    folium.Marker(location=[D1.iloc[i, 1], D1.iloc[i, 2]], icon=folium.Icon(color=D1.iloc[i, 3]), popup=D1.iloc[i, 0]).add_to(map)

# COM3 to Museum
dir_coord_museum = [(D1.iloc[i,2], D1.iloc[i,1]) for i in range(7)]
route = client.directions(coordinates=dir_coord_museum, profile='driving-car', format='geojson')
route_coords_museum = [list(reversed(coord)) for coord in route['features'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords_museum,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

# Museum to UTown
route_coords = [list(reversed(coord)) for coord in museum_to_utown['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

# UTown to YIH
route_coords = [list(reversed(coord)) for coord in utown_to_yih['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

# YIH to COM3
dir_coord_rem = [(D1.iloc[i,2], D1.iloc[i,1]) for i in range(8, len(D1))]
route = client.directions(coordinates=dir_coord_rem, profile='driving-car', format='geojson')
route_coords_rem = [list(reversed(coord)) for coord in route['features'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords_rem,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)


map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f84617fff946d2365adc692477629364 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f84617fff946d2365adc692477629364&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f84617fff946d2365adc692477629364 = L.map(
#                 &quot;map_f84617fff946d2365adc692477629364&quot;,
#                 {
#                     center: [1.2993920113270834, 103.77841451795645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20a370f7a13bd870d0ff870b5b043e20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_20a370f7a13bd870d0ff870b5b043e20.addTo(map_f84617fff946d2365adc692477629364);
#
#
#             var marker_cbc2c6168042e7467cd4d194d8dbf896 = L.marker(
#                 [1.2949617429822875, 103.77496526464915],
#                 {}
#             ).addTo(map_f84617fff946d2365adc692477629364);
#
#
#             var icon_d6f0b4ea42eb6ee73d91dfacacfe906c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cbc2c6168042e7467cd4d194d8dbf896.setIcon(icon_d6f0b4ea42eb6ee73d91dfacacfe906c);
#
#
#         var popup_06de0cac67460c7e3e6e5ace38fa8b9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e0871ad338c8a348a015f7abe17f729 = $(`&lt;div id=&quot;html_6e0871ad338c8a348a015f7abe17f729&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;COM3&lt;/div&gt;`)[0];
#                 popup_06de0cac67460c7e3e6e5ace38fa8b9f.setContent(html_6e0871ad338c8a348a015f7abe17f729);
#
#
#
#         marker_cbc2c6168042e7467cd4d194d8dbf896.bindPopup(popup_06de0cac67460c7e3e6e5ace38fa8b9f)
#         ;
#
#
#
#
#             var marker_72480f8635828151b472832797394585 = L.marker(
#                 [1.2929633209890283, 103.77511784531816],
#                 {}
#             ).addTo(map_f84617fff946d2365adc692477629364);
#
#
#             var icon_5eeeb85336f8592e068aebf2f75950ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_72480f8635828151b472832797394585.setIcon(icon_5eeeb85336f8592e068aebf2f75950ba);
#
#
#         var popup_06a33ce8233443667499a529e3adde58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7e5b9d5df8107d88230ab5eebddffd0 = $(`&lt;div id=&quot;html_f7e5b9d5df8107d88230ab5eebddffd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Opp HSSML&lt;/div&gt;`)[0];
#                 popup_06a33ce8233443667499a529e3adde58.setContent(html_f7e5b9d5df8107d88230ab5eebddffd0);
#
#
#
#         marker_72480f8635828151b472832797394585.bindPopup(popup_06a33ce8233443667499a529e3adde58)
#         ;
#
#
#
#
#             var marker_a4937335f4072ed5e65b95ef8d96451e = L.marker(
#                 [1.293395191541194, 103.77190542434612],
#                 {}
#             ).addTo(map_f84617fff946d2365adc692477629364);
#
#
#             var icon_a817d4977581ec0fd74ccb175692d9fe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a4937335f4072ed5e65b95ef8d96451e.setIcon(icon_a817d4977581ec0fd74ccb175692d9fe);
#
#
#         var popup_4ec102fe3d8f9aa8c41704f2d376f950 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c591d7269952a90dc73a62393a8eb049 = $(`&lt;div id=&quot;html_c591d7269952a90dc73a62393a8eb049&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Opp NUSS&lt;/div&gt;`)[0];
#                 popup_4ec102fe3d8f9aa8c41704f2d376f950.setContent(html_c591d7269952a90dc73a62393a8eb049);
#
#
#
#         marker_a4937335f4072ed5e65b95ef8d96451e.bindPopup(popup_4ec102fe3d8f9aa8c41704f2d376f950)
#         ;
#
#
#
#
#             var marker_bdf083bf4ae6cab4eb4c62fe2c5ebc88 = L.marker(
#                 [1.2953354050928836, 103.77053080902668],
#                 {}
#             ).addTo(map_f84617fff946d2365adc692477629364);
#
#
#             var icon_12c6d0a5ba015224ef0b925961bea519 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:

# %% [markdown]
# ### D2 route

# %% [markdown]
# #### Operating hours
# | Term | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0720 | 2300 |
# | Sun/PH | 0905 | 2300 |

# %% [markdown]
# | Vacation | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0720 | 2300 |
# | Sun/PH | 0905 | 2300 |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday |  | Sun/PH |  |
# | --- | --- | --- | --- | --- | --- |
# | 0715 - 1000 | 5-7 min | 0720 - 1930 | 15 min | 0900 - 2300 | 30 min |
# | 1001 - 1115 | 9-11 min | 1931 - 2300 | 30 min | | |
# | 1116 - 1400 | 5-7 min | | | | |
# | 1401 - 1715 | 7-9 min | | | | |
# | 1716 - 1930 | 5-7 min | | | | |
# | 1931 - 2130 | 10-12 min | | | | |
# | 2131 - 2300 | 15 min | | | | |

# %%
D2_bus = ['COM3', 'Opp TCOMS', 'PGP Terminal', 'KR MRT', 'LT27', 'University Hall', 'Opp UHC', 'Museum', 
          'UTown', 'UHC', 'Opp University Hall', 'S17', 'Opp KR MRT', 'PGP Foyer', 'TCOMS', 'COM3']

D2_stops = bus_stops[bus_stops['Bus Stop'].isin(D2_bus)]
D2_route_df = pd.DataFrame({'Bus Stop': D2_bus})
D2_route_df['route_index'] = D2_route_df.index

D2 = D2_route_df.merge(D2_stops, on='Bus Stop', how='left')
D2.loc[D2['route_index']==0, 'color'] = 'red'
D2.loc[D2['route_index']!=0, 'color'] = 'blue'
D2.loc[D2['route_index']==D2.shape[0]-1, 'color'] = 'red'
D2.drop(columns='route_index', inplace=True)


map = folium.Map(location = [1.2993920113270834, 103.77841451795645], zoom_start = 16)
for i in range(len(D2)):
    folium.Marker(location=[D2.iloc[i, 1], D2.iloc[i, 2]], icon=folium.Icon(color=D2.iloc[i, 3]), popup=D2.iloc[i, 0]).add_to(map)

# # split routes into 3 segments so that the entire route is accurate

# COM3 to Museum
dir_coord_museum = [(D2.iloc[i,2], D2.iloc[i,1]) for i in range(8)]
route = client.directions(coordinates=dir_coord_museum, profile='driving-car', format='geojson')
route_coords_museum = [list(reversed(coord)) for coord in route['features'][0]['geometry']['coordinates']]

folium.PolyLine(locations=route_coords_museum,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

# Museum to UTown
route_coords = [list(reversed(coord)) for coord in museum_to_utown['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

# UTown to UHC
route_coords = [list(reversed(coord)) for coord in utown_to_uhc['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

# UHC to COM3
dir_coord_rem = [(D2.iloc[i,2], D2.iloc[i,1]) for i in range(9, len(D2))]
route = client.directions(coordinates=dir_coord_rem, profile='driving-car', format='geojson')
route_coords_rem = [list(reversed(coord)) for coord in route['features'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords_rem,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d0bc10621be137d049e2c5d7a690093 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d0bc10621be137d049e2c5d7a690093&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d0bc10621be137d049e2c5d7a690093 = L.map(
#                 &quot;map_6d0bc10621be137d049e2c5d7a690093&quot;,
#                 {
#                     center: [1.2993920113270834, 103.77841451795645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a7d9b6fd61b8d0016ab07b17c9988ec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1a7d9b6fd61b8d0016ab07b17c9988ec.addTo(map_6d0bc10621be137d049e2c5d7a690093);
#
#
#             var marker_d0c5021c5b5b028eb6a341b9f58b1cc1 = L.marker(
#                 [1.2949617429822875, 103.77496526464915],
#                 {}
#             ).addTo(map_6d0bc10621be137d049e2c5d7a690093);
#
#
#             var icon_3cf8e5885b2bb106cefa479045df4635 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d0c5021c5b5b028eb6a341b9f58b1cc1.setIcon(icon_3cf8e5885b2bb106cefa479045df4635);
#
#
#         var popup_71b189819d61174ab0c1159fae4a14dc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c50889f3667b2f875ccbe8c2eea93d48 = $(`&lt;div id=&quot;html_c50889f3667b2f875ccbe8c2eea93d48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;COM3&lt;/div&gt;`)[0];
#                 popup_71b189819d61174ab0c1159fae4a14dc.setContent(html_c50889f3667b2f875ccbe8c2eea93d48);
#
#
#
#         marker_d0c5021c5b5b028eb6a341b9f58b1cc1.bindPopup(popup_71b189819d61174ab0c1159fae4a14dc)
#         ;
#
#
#
#
#             var marker_ee2dd45d40da5da3867163370c89b933 = L.marker(
#                 [1.2937113340845738, 103.77700719838774],
#                 {}
#             ).addTo(map_6d0bc10621be137d049e2c5d7a690093);
#
#
#             var icon_fc29e15a404bc6c5e03a195a90dae8c1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ee2dd45d40da5da3867163370c89b933.setIcon(icon_fc29e15a404bc6c5e03a195a90dae8c1);
#
#
#         var popup_7136254ccc21209768c69337f20eefdf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_91f68819eaba2d525ab2222b09b110ae = $(`&lt;div id=&quot;html_91f68819eaba2d525ab2222b09b110ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Opp TCOMS&lt;/div&gt;`)[0];
#                 popup_7136254ccc21209768c69337f20eefdf.setContent(html_91f68819eaba2d525ab2222b09b110ae);
#
#
#
#         marker_ee2dd45d40da5da3867163370c89b933.bindPopup(popup_7136254ccc21209768c69337f20eefdf)
#         ;
#
#
#
#
#             var marker_876ff616dd39e7ba43a1fc81d6745843 = L.marker(
#                 [1.2918452689707198, 103.78043600861773],
#                 {}
#             ).addTo(map_6d0bc10621be137d049e2c5d7a690093);
#
#
#             var icon_b0673fff071d9eb9d981cf4bd4407c77 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_876ff616dd39e7ba43a1fc81d6745843.setIcon(icon_b0673fff071d9eb9d981cf4bd4407c77);
#
#
#         var popup_8363807035eba9de2a110c5d0cec15c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c65e13c8654751f9cbe37500409adf40 = $(`&lt;div id=&quot;html_c65e13c8654751f9cbe37500409adf40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PGP Terminal&lt;/div&gt;`)[0];
#                 popup_8363807035eba9de2a110c5d0cec15c2.setContent(html_c65e13c8654751f9cbe37500409adf40);
#
#
#
#         marker_876ff616dd39e7ba43a1fc81d6745843.bindPopup(popup_8363807035eba9de2a110c5d0cec15c2)
#         ;
#
#
#
#
#             var marker_14f5d5ed02c8bff08b7ef5873826cd26 = L.marker(
#                 [1.2948032131296237, 103.7843978019587],
#                 {}
#             ).addTo(map_6d0bc10621be137d049e2c5d7a690093);
#
#
#             var icon_70b64d15f0bfc8423f8b0b2cc98d7b9c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&qu

# %% [markdown]
# ### BTC route

# %% [markdown]
# #### Operating hours
# | Term | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0730 | 2140 |
# | Saturday | No service |
# | Sun/PH | No service |

# %% [markdown]
# | Vacation | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0730 | 1940 |
# | Saturday | No service |
# | Sun/PH | No service |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday |  Sun/PH |
# | --- | --- | --- | --- |
# | 0730 - 1000 | 30 min | No service |  No service |
# | 1001 - 1110 | 35 min |
# | 1111 - 1410 | 30 min |
# | 1401 - 1710 | 45 min |
# | 1711 - 1940 | 30 min |
# | 1941 - 2110 | 45 min |
# | 2111 - 2140 | 30 min |

# %%
btc_url = 'https://api.mapbox.com/directions/v5/mapbox/driving/103.817832%2C1.319848%3B103.818893%2C1.320928%3B103.815903%2C1.32268%3B103.784429%2C1.294841%3B103.780988%2C1.297413%3B103.778766%2C1.297204%3B103.775656%2C1.29881%3B103.774434%2C1.303535%3B103.772749%2C1.301005%3B103.769636%2C1.301896%3B103.769058%2C1.302245%3B103.773469%2C1.301136%3B103.774308%2C1.298863%3B103.772194%2C1.296321%3B103.770581%2C1.294841%3B103.771738%2C1.293506%3B103.775121%2C1.29325%3B103.780403%2C1.291822%3B103.816278%2C1.323278%3B103.81827%2C1.319337?alternatives=false&geometries=geojson&language=en&overview=full&steps=true&access_token=pk.eyJ1IjoiZ3VvaG9uZ3lpMTExIiwiYSI6ImNtMng0OHc4cTAwenMybG9iczg4cjBoNjcifQ.tc6o1kU_mTemKQhbVy5mNA'
response = requests.get(btc_url)
btc_route = response.json()

# %%
BTC_bus = ['Oei Tiong Ham Building (BTC)', 'Botanic Gardens MRT (BTC)', 'KR MRT', 'LT27', 'University Hall', 'Opp UHC', 
           'UTown', 'Raffles Hall', 'Kent Vale', 'Museum', 'YIH', 'CLB', 'LT13', 'AS5', 'BIZ2', 'PGP Terminal', 'College Green (BTC)', 
           'Oei Tiong Ham Building (BTC)']

BTC_stops = bus_stops[bus_stops['Bus Stop'].isin(BTC_bus)]
BTC_route_df = pd.DataFrame({'Bus Stop': BTC_bus})
BTC_route_df['route_index'] = BTC_route_df.index

BTC = BTC_route_df.merge(BTC_stops, on='Bus Stop', how='left')
BTC.loc[BTC['route_index']==0, 'color'] = 'red'
BTC.loc[BTC['route_index']!=0, 'color'] = 'blue'
BTC.loc[BTC['route_index']==BTC.shape[0]-1, 'color'] = 'red'
BTC.drop(columns='route_index', inplace=True)

map = folium.Map(location = [1.2993920113270834, 103.77841451795645], zoom_start = 14)
for i in range(len(BTC)):
    folium.Marker(location=[BTC.iloc[i, 1], BTC.iloc[i, 2]], icon=folium.Icon(color=BTC.iloc[i, 3]), popup=BTC.iloc[i, 0]).add_to(map)

route_coords = [list(reversed(coord)) for coord in btc_route['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d0aaf405b65729e7a7e3e0f5d53c349 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d0aaf405b65729e7a7e3e0f5d53c349&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d0aaf405b65729e7a7e3e0f5d53c349 = L.map(
#                 &quot;map_1d0aaf405b65729e7a7e3e0f5d53c349&quot;,
#                 {
#                     center: [1.2993920113270834, 103.77841451795645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d3b1c21053263bce3ec8e12a0fc0077 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6d3b1c21053263bce3ec8e12a0fc0077.addTo(map_1d0aaf405b65729e7a7e3e0f5d53c349);
#
#
#             var marker_c7b548458b7321b8d0e6a59c9eb0c984 = L.marker(
#                 [1.3198303112461514, 103.81775937050531],
#                 {}
#             ).addTo(map_1d0aaf405b65729e7a7e3e0f5d53c349);
#
#
#             var icon_fc17d81c17c212b0a250968bec67530d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c7b548458b7321b8d0e6a59c9eb0c984.setIcon(icon_fc17d81c17c212b0a250968bec67530d);
#
#
#         var popup_e309320279c398f3e2b28a11db63bdec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_05b12369a18731679d8f740081f88777 = $(`&lt;div id=&quot;html_05b12369a18731679d8f740081f88777&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Oei Tiong Ham Building (BTC)&lt;/div&gt;`)[0];
#                 popup_e309320279c398f3e2b28a11db63bdec.setContent(html_05b12369a18731679d8f740081f88777);
#
#
#
#         marker_c7b548458b7321b8d0e6a59c9eb0c984.bindPopup(popup_e309320279c398f3e2b28a11db63bdec)
#         ;
#
#
#
#
#             var marker_d75f8c04488e45e1c95be14021fdf17c = L.marker(
#                 [1.3227333266951262, 103.8151647850129],
#                 {}
#             ).addTo(map_1d0aaf405b65729e7a7e3e0f5d53c349);
#
#
#             var icon_8af59c8ae3340f4ec1fc019a0f48aecf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d75f8c04488e45e1c95be14021fdf17c.setIcon(icon_8af59c8ae3340f4ec1fc019a0f48aecf);
#
#
#         var popup_d3184a253e7c76009632de41fb259e64 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_42a823f6733d02b46a08d7c72ca3118a = $(`&lt;div id=&quot;html_42a823f6733d02b46a08d7c72ca3118a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Botanic Gardens MRT (BTC)&lt;/div&gt;`)[0];
#                 popup_d3184a253e7c76009632de41fb259e64.setContent(html_42a823f6733d02b46a08d7c72ca3118a);
#
#
#
#         marker_d75f8c04488e45e1c95be14021fdf17c.bindPopup(popup_d3184a253e7c76009632de41fb259e64)
#         ;
#
#
#
#
#             var marker_fa9ecc19a03683517441046c1068b77d = L.marker(
#                 [1.2948032131296237, 103.7843978019587],
#                 {}
#             ).addTo(map_1d0aaf405b65729e7a7e3e0f5d53c349);
#
#
#             var icon_b5a7fe1258425bef875d891a3782989e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fa9ecc19a03683517441046c1068b77d.setIcon(icon_b5a7fe1258425bef875d891a3782989e);
#
#
#         var popup_c5ac1caaca9a59d2174a5d96e2c866e6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb97d0aafd23478a2870808529229a28 = $(`&lt;div id=&quot;html_bb97d0aafd23478a2870808529229a28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KR MRT&lt;/div&gt;`)[0];
#                 popup_c5ac1caaca9a59d2174a5d96e2c866e6.setContent(html_bb97d0aafd23478a2870808529229a28);
#
#
#
#         marker_fa9ecc19a03683517441046c1068b77d.bindPopup(popup_c5ac1caaca9a59d2174a5d96e2c866e6)
#         ;
#
#
#
#
#             var marker_d300ceac805206d02387062cfd0fd2b0 = L.marker(
#                 [1.297352137914635, 103.78095164513468],
#                 {}
#             ).addTo(map_1d0aaf405b65729e7a7e3e0f5d53c349);
#
#
#             var icon_4d3a28ecde1dc7d11688650a87ee6f8e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;

# %% [markdown]
# ### E route

# %% [markdown]
# #### Operating hours
# | Term | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0800 | 1600 |
# | Saturday | No service |
# | Sun/PH | No service |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday | Sun/PH |
# | --- | --- | --- | --- |
# | 0800 - 1000 | 15 min | No service | No service |
# | 1115 - 1400 | 15 min |
# | 1515 - 1600 | 15 min |

# %%
E_url = 'https://api.mapbox.com/directions/v5/mapbox/driving/103.774437%2C1.303529%3B103.772744%2C1.301%3B103.769629%2C1.301897%3B103.769053%2C1.302199%3B103.770144%2C1.300623%3B103.769865%2C1.297757%3B103.77271%2C1.297189%3B103.774132%2C1.298847%3B103.774415%2C1.303511?alternatives=false&geometries=geojson&language=en&overview=full&steps=true&access_token=pk.eyJ1IjoiZ3VvaG9uZ3lpMTExIiwiYSI6ImNtMng0OHc4cTAwenMybG9iczg4cjBoNjcifQ.tc6o1kU_mTemKQhbVy5mNA'
responses = requests.get(E_url)
E_route = responses.json()

# %%
E_bus = ['UTown', 'Raffles Hall', 'Kent Vale', 'EA', 'SDE3', 'IT', 'Opp YIH', 'UTown']

E_stops = bus_stops[bus_stops['Bus Stop'].isin(E_bus)]
E_route_df = pd.DataFrame({'Bus Stop': E_bus})
E_route_df['route_index'] = E_route_df.index

E = E_route_df.merge(E_stops, on='Bus Stop', how='left')
E.loc[E['route_index']==0, 'color'] = 'red'
E.loc[E['route_index']!=0, 'color'] = 'blue'
E.loc[E['route_index']==E.shape[0]-1, 'color'] = 'red'
E.drop(columns='route_index', inplace=True)


map = folium.Map(location = [1.3002841404515253, 103.77231795009253], zoom_start = 17)
for i in range(len(E)):
    folium.Marker(location=[E.iloc[i, 1], E.iloc[i, 2]], icon=folium.Icon(color=E.iloc[i, 3]), popup=E.iloc[i, 0]).add_to(map)


route_coords = [list(reversed(coord)) for coord in E_route['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6dc2b89ba214635771e8adb66de8e89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6dc2b89ba214635771e8adb66de8e89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6dc2b89ba214635771e8adb66de8e89 = L.map(
#                 &quot;map_e6dc2b89ba214635771e8adb66de8e89&quot;,
#                 {
#                     center: [1.3002841404515253, 103.77231795009253],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc1765ced1afa6811bf4f2489f19e265 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bc1765ced1afa6811bf4f2489f19e265.addTo(map_e6dc2b89ba214635771e8adb66de8e89);
#
#
#             var marker_8bace5211703d8431b80137f70cb2d23 = L.marker(
#                 [1.3035546593332374, 103.77441438310554],
#                 {}
#             ).addTo(map_e6dc2b89ba214635771e8adb66de8e89);
#
#
#             var icon_70c7cadb269701706c69ab653cb3c69f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8bace5211703d8431b80137f70cb2d23.setIcon(icon_70c7cadb269701706c69ab653cb3c69f);
#
#
#         var popup_023a2cb3aef0bd2d5fec1b221de9dc04 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7915630a2da667dbedeb574a1c5d59cc = $(`&lt;div id=&quot;html_7915630a2da667dbedeb574a1c5d59cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTown&lt;/div&gt;`)[0];
#                 popup_023a2cb3aef0bd2d5fec1b221de9dc04.setContent(html_7915630a2da667dbedeb574a1c5d59cc);
#
#
#
#         marker_8bace5211703d8431b80137f70cb2d23.bindPopup(popup_023a2cb3aef0bd2d5fec1b221de9dc04)
#         ;
#
#
#
#
#             var marker_cab0bcd988cff6d258925278ff396a4e = L.marker(
#                 [1.300977165579121, 103.77270175961483],
#                 {}
#             ).addTo(map_e6dc2b89ba214635771e8adb66de8e89);
#
#
#             var icon_17800eb4208e86c00a8071b21d66d720 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cab0bcd988cff6d258925278ff396a4e.setIcon(icon_17800eb4208e86c00a8071b21d66d720);
#
#
#         var popup_4253482965a1f0038cb752309a6681fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ebf7974cda7b8d12dd79e99e2a86b426 = $(`&lt;div id=&quot;html_ebf7974cda7b8d12dd79e99e2a86b426&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Raffles Hall&lt;/div&gt;`)[0];
#                 popup_4253482965a1f0038cb752309a6681fa.setContent(html_ebf7974cda7b8d12dd79e99e2a86b426);
#
#
#
#         marker_cab0bcd988cff6d258925278ff396a4e.bindPopup(popup_4253482965a1f0038cb752309a6681fa)
#         ;
#
#
#
#
#             var marker_1c5dbaaadc947cc792df4e982cb8fc0d = L.marker(
#                 [1.3019605740478033, 103.7694762443471],
#                 {}
#             ).addTo(map_e6dc2b89ba214635771e8adb66de8e89);
#
#
#             var icon_b829560c2d787ef919f2fcd0190486b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1c5dbaaadc947cc792df4e982cb8fc0d.setIcon(icon_b829560c2d787ef919f2fcd0190486b5);
#
#
#         var popup_9523789ca31c106e5ce6d2b78b57786a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7227e8514a75b722c815e2385ace77a3 = $(`&lt;div id=&quot;html_7227e8514a75b722c815e2385ace77a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kent Vale&lt;/div&gt;`)[0];
#                 popup_9523789ca31c106e5ce6d2b78b57786a.setContent(html_7227e8514a75b722c815e2385ace77a3);
#
#
#
#         marker_1c5dbaaadc947cc792df4e982cb8fc0d.bindPopup(popup_9523789ca31c106e5ce6d2b78b57786a)
#         ;
#
#
#
#
#             var marker_37ecc07dcc103c8d4f626642e52ea6e0 = L.marker(
#                 [1.3006008936256923, 103.77017267417776],
#                 {}
#             ).addTo(map_e6dc2b89ba214635771e8adb66de8e89);
#
#
#             var icon_4f41e0506a73da9b65fd552681f90b5a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&qu

# %% [markdown]
# ### K route

# %% [markdown]
# #### Operating hours
# | Term/Vacation | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0700 | 2300 |
# | Saturday | 0700 | 1930 |
# | Sun/PH | No service |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday | | Sun/PH |
# | --- | --- | --- | --- | --- |
# | 0700 - 2300 | 40 min | 0700 - 1930 | 40 min | No service |

# %%
K_url = 'https://api.mapbox.com/directions/v5/mapbox/driving/103.78039%2C1.2918%3B103.784424%2C1.294834%3B103.780996%2C1.297405%3B103.778771%2C1.297191%3B103.775658%2C1.298817%3B103.774306%2C1.298857%3B103.772199%2C1.296316%3B103.769637%2C1.297888%3B103.769957%2C1.300739%3B103.769629%2C1.301901%3B103.769015%2C1.302229%3B103.773468%2C1.301142%3B103.77606%2C1.298901%3B103.778076%2C1.297504%3B103.780704%2C1.297515%3B103.784574%2C1.294956%3B103.781073%2C1.290993?alternatives=false&geometries=geojson&language=en&overview=full&steps=true&access_token=pk.eyJ1IjoiZ3VvaG9uZ3lpMTExIiwiYSI6ImNtMng0OHc4cTAwenMybG9iczg4cjBoNjcifQ.tc6o1kU_mTemKQhbVy5mNA'
responses = requests.get(K_url)
K_route = responses.json()

# %%
K_bus = ['PGP Terminal', 'KR MRT', 'LT27', 'University Hall', 'Opp UHC', 'YIH', 'CLB', 'Opp SDE3', 'The Japanese Primary School', 
         'Kent Vale', 'Museum', 'UHC', 'Opp University Hall', 'S17', 'Opp KR MRT', 'PGP Foyer']

K_stops = bus_stops[bus_stops['Bus Stop'].isin(K_bus)]
K_route_df = pd.DataFrame({'Bus Stop': K_bus})
K_route_df['route_index'] = K_route_df.index

K = K_route_df.merge(K_stops, on='Bus Stop', how='left')
K.loc[K['route_index']==0, 'color'] = 'red'
K.loc[K['route_index']!=0, 'color'] = 'blue'
K.loc[K['route_index']==K.shape[0]-1, 'color'] = 'red'
K.drop(columns='route_index', inplace=True)

map = folium.Map(location = [1.2993920113270834, 103.77841451795645], zoom_start = 16)
for i in range(len(K)):
    folium.Marker(location=[K.iloc[i, 1], K.iloc[i, 2]], icon=folium.Icon(color=K.iloc[i, 3]), popup=K.iloc[i, 0]).add_to(map)

route_coords = [list(reversed(coord)) for coord in K_route['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6bb81ec0f54ad9020b89cfa6bb2dcf0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6bb81ec0f54ad9020b89cfa6bb2dcf0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6bb81ec0f54ad9020b89cfa6bb2dcf0 = L.map(
#                 &quot;map_d6bb81ec0f54ad9020b89cfa6bb2dcf0&quot;,
#                 {
#                     center: [1.2993920113270834, 103.77841451795645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc60a05426f94a0e5c3853f048fdd02b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bc60a05426f94a0e5c3853f048fdd02b.addTo(map_d6bb81ec0f54ad9020b89cfa6bb2dcf0);
#
#
#             var marker_43ee8944c54aff7e1e856eed66d52402 = L.marker(
#                 [1.2918452689707198, 103.78043600861773],
#                 {}
#             ).addTo(map_d6bb81ec0f54ad9020b89cfa6bb2dcf0);
#
#
#             var icon_eb53cfd961a7023191e8158f98e91439 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_43ee8944c54aff7e1e856eed66d52402.setIcon(icon_eb53cfd961a7023191e8158f98e91439);
#
#
#         var popup_a83e66fa633e9af5b56a7aa5fe5364c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_01dda4ff6175809c71664e5013ebda7b = $(`&lt;div id=&quot;html_01dda4ff6175809c71664e5013ebda7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PGP Terminal&lt;/div&gt;`)[0];
#                 popup_a83e66fa633e9af5b56a7aa5fe5364c9.setContent(html_01dda4ff6175809c71664e5013ebda7b);
#
#
#
#         marker_43ee8944c54aff7e1e856eed66d52402.bindPopup(popup_a83e66fa633e9af5b56a7aa5fe5364c9)
#         ;
#
#
#
#
#             var marker_51dc56f3b390e1e51c2ab8dbd05fe26a = L.marker(
#                 [1.2948032131296237, 103.7843978019587],
#                 {}
#             ).addTo(map_d6bb81ec0f54ad9020b89cfa6bb2dcf0);
#
#
#             var icon_59f62380de9370c42bfce271430221b5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_51dc56f3b390e1e51c2ab8dbd05fe26a.setIcon(icon_59f62380de9370c42bfce271430221b5);
#
#
#         var popup_66bda9d372b2e719a51bdbb5816b79c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_77062c8e514e68c829b60598460437c7 = $(`&lt;div id=&quot;html_77062c8e514e68c829b60598460437c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KR MRT&lt;/div&gt;`)[0];
#                 popup_66bda9d372b2e719a51bdbb5816b79c2.setContent(html_77062c8e514e68c829b60598460437c7);
#
#
#
#         marker_51dc56f3b390e1e51c2ab8dbd05fe26a.bindPopup(popup_66bda9d372b2e719a51bdbb5816b79c2)
#         ;
#
#
#
#
#             var marker_761e78b1bc53932ffa9ec4ad3e023415 = L.marker(
#                 [1.297352137914635, 103.78095164513468],
#                 {}
#             ).addTo(map_d6bb81ec0f54ad9020b89cfa6bb2dcf0);
#
#
#             var icon_792b3bc4df93c4809c90de5b9164d850 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_761e78b1bc53932ffa9ec4ad3e023415.setIcon(icon_792b3bc4df93c4809c90de5b9164d850);
#
#
#         var popup_9778a9a7c072eb5157abeb74a8337905 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_927d352d61966a3838ae4a958f5e380d = $(`&lt;div id=&quot;html_927d352d61966a3838ae4a958f5e380d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LT27&lt;/div&gt;`)[0];
#                 popup_9778a9a7c072eb5157abeb74a8337905.setContent(html_927d352d61966a3838ae4a958f5e380d);
#
#
#
#         marker_761e78b1bc53932ffa9ec4ad3e023415.bindPopup(popup_9778a9a7c072eb5157abeb74a8337905)
#         ;
#
#
#
#
#             var marker_8a2d76c1ee8a7c20720e91f8ce6fc061 = L.marker(
#                 [1.297130588212707, 103.77879580832035],
#                 {}
#             ).addTo(map_d6bb81ec0f54ad9020b89cfa6bb2dcf0);
#
#
#             var icon_ae2fdf4c333756015ff8a2c46684646e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:
