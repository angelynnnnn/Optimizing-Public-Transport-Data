# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import openrouteservice as ors
import requests

# %%
API_KEY = '5b3ce3597851110001cf62484364c6151eb540e3949acae6888d47ef'

client = ors.Client(key=API_KEY)

# %% [markdown]
# ## Visualizing bus routes

# %%
bus_stops = pd.read_csv('bus_stop_coords.csv', header=None)
bus_stops.rename(columns={0:"Bus Stop", 1:"x", 2:"y"}, inplace=True)
bus_stops
# Out:
#                         Bus Stop         x           y
# 0                          UTown  1.303555  103.774414
# 1                         Museum  1.301081  103.773694
# 2                            UHC  1.298913  103.776112
# 3                        Opp UHC  1.298789  103.775627
# 4                        Opp YIH  1.298973  103.774179
# 5                            YIH  1.298898  103.774388
# 6                             IT  1.297234  103.772697
# 7                            CLB  1.296365  103.772261
# 8                         Ventus  1.295335  103.770531
# 9                           LT13  1.294727  103.770627
# 10                      Opp NUSS  1.293395  103.771905
# 11                           AS5  1.293502  103.771859
# 12                          BIZ2  1.293238  103.775127
# 13                     Opp HSSML  1.292963  103.775118
# 14                          COM3  1.294962  103.774965
# 15                     Opp TCOMS  1.293711  103.777007
# 16                         TCOMS  1.293597  103.777066
# 17                  PGP Terminal  1.291845  103.780436
# 18                     PGP Foyer  1.291019  103.781156
# 19                        KR MRT  1.294803  103.784398
# 20                    Opp KR MRT  1.295020  103.784567
# 21                          LT27  1.297352  103.780952
# 22                           S17  1.297523  103.780730
# 23               University Hall  1.297131  103.778796
# 24           Opp University Hall  1.297521  103.778127
# 25               KR Bus Terminal  1.294284  103.769710
# 26                  Raffles Hall  1.300977  103.772702
# 27                     Kent Vale  1.301961  103.769476
# 28                            EA  1.300601  103.770173
# 29                          SDE3  1.297816  103.769936
# 30                      Opp SDE3  1.297832  103.769587
# 31   The Japanese Primary School  1.300763  103.769932
# 32     Botanic Gardens MRT (BTC)  1.322733  103.815165
# 33           College Green (BTC)  1.323395  103.816267
# 34  Oei Tiong Ham Building (BTC)  1.319830  103.817759

# %% [markdown]
# ### All bus stops

# %%
map = folium.Map(location = [1.3083003040174188, 103.79569430095988], zoom_start = 15)
for i in range(len(bus_stops)):
    folium.Marker(location=[bus_stops.iloc[i, 1], bus_stops.iloc[i, 2]], colors='grey').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3435ac045c2679fdbd6d67c73e5432f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3435ac045c2679fdbd6d67c73e5432f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3435ac045c2679fdbd6d67c73e5432f = L.map(
#                 &quot;map_d3435ac045c2679fdbd6d67c73e5432f&quot;,
#                 {
#                     center: [1.3083003040174188, 103.79569430095988],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bced2d4ac29be85a1e657f220f2c6304 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bced2d4ac29be85a1e657f220f2c6304.addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_de61700d2bf6109b05aeea06b2878d5d = L.marker(
#                 [1.3035546593332374, 103.77441438310554],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_95e815e7e96aadfd91ffa786dbb27c35 = L.marker(
#                 [1.3010811364904713, 103.77369406623278],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_6fc2fda37415976b0a959e7243575627 = L.marker(
#                 [1.2989132429412726, 103.77611186756018],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_2c7db2abd6f0c751df1ea7d38d22b41f = L.marker(
#                 [1.2987886001367377, 103.775626526238],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_631fdb85f76541f63f0ec4849f8304ae = L.marker(
#                 [1.2989725099505092, 103.77417867705664],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_462d46dfd779cc0c7527d7131a21bc56 = L.marker(
#                 [1.2988982413553634, 103.77438843051462],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_d89bcce0281b8896bb2dd2b916ac707d = L.marker(
#                 [1.297233750488144, 103.77269729320729],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_19b75af15edcc02d430f6986520a432e = L.marker(
#                 [1.296365, 103.772261],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_f14e1fc393f9a9574873bf2cc08ec4f1 = L.marker(
#                 [1.2953354050928836, 103.77053080902668],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_54e7b0440077c50428765810c7ab1c8e = L.marker(
#                 [1.2947269559634624, 103.77062733455368],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_dc6a402d83c9a3b23d69c938d807f929 = L.marker(
#                 [1.293395191541194, 103.77190542434612],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_934890580cc078ac860d205fe0f66c80 = L.marker(
#                 [1.293502262315002, 103.7718589614246],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_127efdc437ee40a48b1e44e852808965 = L.marker(
#                 [1.293237778373149, 103.7751270971964],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_3dba2060af74fdb270e233b4c8275d2a = L.marker(
#                 [1.2929633209890283, 103.77511784531816],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_6ab54baf55aa9555df504e6389f10f22 = L.marker(
#                 [1.2949617429822875, 103.77496526464915],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_b04cb84583ad4c467990fe8c97c61ce2 = L.marker(
#                 [1.2937113340845738, 103.77700719838774],
#                 {&quot;colors&quot;: &quot;grey&quot;}
#             ).addTo(map_d3435ac045c2679fdbd6d67c73e5432f);
#
#
#             var marker_d7749c0573229ba5a0e867d1fb5088d4 = L.marker(
#                 [1.29

# %% [markdown]
# ### A1 route

# %% [markdown]
# #### Operating hours
# | Term | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0715 | 2300 |
# | Sun/PH | 0900 | 2300 |

# %% [markdown]
# | Vacation | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0715 | 2300 |
# | Sun/PH | 0900 | 2300 |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday |  | Sun/PH |  |
# | --- | --- | --- | --- | --- | --- |
# | 0715 - 0800 | 8-10 min | 0715 - 1930 | 15 min | 0900 - 2300 | 30 min |
# | 0801 - 1000 | 4-6 min | 1931 - 2300 | 30 min | | |
# | 1001 - 1100 | 10-12 min | | | | |
# | 1101 - 1400 | 5-7 min | | | | |
# | 1401 - 1715 | 8-10 min | | | | |
# | 1716 - 1930 | 5-7 min | | | | |
# | 1931 - 2300 | 15 min | | | | |

# %%
A1_bus = ['KR Bus Terminal', 'LT13', 'AS5', 'BIZ2', 'Opp TCOMS', 'PGP Terminal', 'KR MRT', 'LT27', 
          'University Hall', 'Opp UHC', 'YIH', 'CLB', 'KR Bus Terminal']

A1_stops = bus_stops[bus_stops['Bus Stop'].isin(A1_bus)]
A1_route_df = pd.DataFrame({'Bus Stop': A1_bus})
A1_route_df['route_index'] = A1_route_df.index

A1 = A1_route_df.merge(A1_stops, on='Bus Stop', how='left')
A1.loc[A1['route_index']==0, 'color'] = 'red'
A1.loc[A1['route_index']!=0, 'color'] = 'blue'
A1.loc[A1['route_index']==A1.shape[0]-1, 'color'] = 'red'
A1.drop(columns='route_index', inplace=True)


map = folium.Map(location = [1.2993920113270834, 103.77841451795645], zoom_start = 16)
for i in range(len(A1)):
    folium.Marker(location=[A1.iloc[i, 1], A1.iloc[i, 2]], icon=folium.Icon(color=A1.iloc[i, 3]), popup=A1.iloc[i, 0]).add_to(map)

dir_coord = [(A1.iloc[i,2], A1.iloc[i,1]) for i in range(len(A1))]
route = client.directions(coordinates=dir_coord, profile='driving-car', format='geojson', optimize_waypoints=True)
route_coords = [list(reversed(coord)) for coord in route['features'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6be92c30258b1b3c5daeab158cf256ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6be92c30258b1b3c5daeab158cf256ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6be92c30258b1b3c5daeab158cf256ea = L.map(
#                 &quot;map_6be92c30258b1b3c5daeab158cf256ea&quot;,
#                 {
#                     center: [1.2993920113270834, 103.77841451795645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1236b1c1db6bb334168b20595284f76 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d1236b1c1db6bb334168b20595284f76.addTo(map_6be92c30258b1b3c5daeab158cf256ea);
#
#
#             var marker_64567dec2d1226ed32c9b0b04bb83ef5 = L.marker(
#                 [1.294284039296162, 103.7697100325711],
#                 {}
#             ).addTo(map_6be92c30258b1b3c5daeab158cf256ea);
#
#
#             var icon_1e46e2607d01e1cd556f3d6fcac0910a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_64567dec2d1226ed32c9b0b04bb83ef5.setIcon(icon_1e46e2607d01e1cd556f3d6fcac0910a);
#
#
#         var popup_5c2bca3f98438d8c0fb1f2144985de00 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c76cafc7b654a1ba4483e969f46908d8 = $(`&lt;div id=&quot;html_c76cafc7b654a1ba4483e969f46908d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KR Bus Terminal&lt;/div&gt;`)[0];
#                 popup_5c2bca3f98438d8c0fb1f2144985de00.setContent(html_c76cafc7b654a1ba4483e969f46908d8);
#
#
#
#         marker_64567dec2d1226ed32c9b0b04bb83ef5.bindPopup(popup_5c2bca3f98438d8c0fb1f2144985de00)
#         ;
#
#
#
#
#             var marker_a63e890f44410c50c36c3465d2f557a1 = L.marker(
#                 [1.2947269559634624, 103.77062733455368],
#                 {}
#             ).addTo(map_6be92c30258b1b3c5daeab158cf256ea);
#
#
#             var icon_449d65c42252e5296c9d2597c1a8347e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a63e890f44410c50c36c3465d2f557a1.setIcon(icon_449d65c42252e5296c9d2597c1a8347e);
#
#
#         var popup_5e9657c6e4999ec534b98d8ab810348a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_643fdf0f5bca656f5c7d778af1531560 = $(`&lt;div id=&quot;html_643fdf0f5bca656f5c7d778af1531560&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LT13&lt;/div&gt;`)[0];
#                 popup_5e9657c6e4999ec534b98d8ab810348a.setContent(html_643fdf0f5bca656f5c7d778af1531560);
#
#
#
#         marker_a63e890f44410c50c36c3465d2f557a1.bindPopup(popup_5e9657c6e4999ec534b98d8ab810348a)
#         ;
#
#
#
#
#             var marker_b601d5f1d5135d1c03206adabe45c795 = L.marker(
#                 [1.293502262315002, 103.7718589614246],
#                 {}
#             ).addTo(map_6be92c30258b1b3c5daeab158cf256ea);
#
#
#             var icon_bbf993056a7c6b6c51d9d76a240d5900 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b601d5f1d5135d1c03206adabe45c795.setIcon(icon_bbf993056a7c6b6c51d9d76a240d5900);
#
#
#         var popup_74547b2dbf9331b390ab3d41f068d360 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bde18c0c64696f9774b2ac0adefb3c8 = $(`&lt;div id=&quot;html_1bde18c0c64696f9774b2ac0adefb3c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AS5&lt;/div&gt;`)[0];
#                 popup_74547b2dbf9331b390ab3d41f068d360.setContent(html_1bde18c0c64696f9774b2ac0adefb3c8);
#
#
#
#         marker_b601d5f1d5135d1c03206adabe45c795.bindPopup(popup_74547b2dbf9331b390ab3d41f068d360)
#         ;
#
#
#
#
#             var marker_e61491741c3bd139ef290cabd53543e4 = L.marker(
#                 [1.293237778373149, 103.7751270971964],
#                 {}
#             ).addTo(map_6be92c30258b1b3c5daeab158cf256ea);
#
#
#             var icon_52dac46b5239a367c4412d3e2d9a3b9e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &qu

# %% [markdown]
# ### A2 route

# %% [markdown]
# #### Operating hours
# | Term | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0715 | 2300 |
# | Sun/PH | 0900 | 2300 |

# %% [markdown]
# | Vacation | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0715 | 2300 |
# | Sun/PH | 0900 | 2300 |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday |  | Sun/PH |  |
# | --- | --- | --- | --- | --- | --- |
# | 0715 - 1000 | 6-8 min | 0715 - 1930 | 15 min | 0900 - 2300 | 30 min |
# | 1001 - 1115 | 9-11 min | 1931 - 2300 | 30 min | | |
# | 1116 - 1400 | 6-8 min | | | | |
# | 1401 - 1700 | 7-10 min | | | | |
# | 1701 - 1930 | 6-8 min | | | | |
# | 1931 - 2130 | 11-13 min | | | | |
# | 2131 - 2300 | 15 min | | | | |

# %%
A2_bus = ['KR Bus Terminal', 'IT', 'Opp YIH', 'Museum', 'UHC', 'Opp University Hall', 'S17', 'Opp KR MRT', 
          'PGP Foyer', 'TCOMS', 'Opp HSSML', 'Opp NUSS', 'Ventus', 'KR Bus Terminal']

A2_stops = bus_stops[bus_stops['Bus Stop'].isin(A2_bus)]
A2_route_df = pd.DataFrame({'Bus Stop': A2_bus})
A2_route_df['route_index'] = A2_route_df.index

A2 = A2_route_df.merge(A2_stops, on='Bus Stop', how='left')
A2.loc[A2['route_index']==0, 'color'] = 'red'
A2.loc[A2['route_index']!=0, 'color'] = 'blue'
A2.loc[A2['route_index']==A2.shape[0]-1, 'color'] = 'red'
A2.drop(columns='route_index', inplace=True)


map = folium.Map(location = [1.2993920113270834, 103.77841451795645], zoom_start = 16)
for i in range(len(A2)):
    folium.Marker(location=[A2.iloc[i, 1], A2.iloc[i, 2]], icon=folium.Icon(color=A2.iloc[i, 3]), popup=A2.iloc[i, 0]).add_to(map)

dir_coord = [(A2.iloc[i,2], A2.iloc[i,1]) for i in range(len(A2))]
route = client.directions(coordinates=dir_coord, profile='driving-car', format='geojson', optimize_waypoints=True)
route_coords = [list(reversed(coord)) for coord in route['features'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a25558255bc853fed530d96063827584 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a25558255bc853fed530d96063827584&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a25558255bc853fed530d96063827584 = L.map(
#                 &quot;map_a25558255bc853fed530d96063827584&quot;,
#                 {
#                     center: [1.2993920113270834, 103.77841451795645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_032fb6899c6c07ef5e8f47ab6cb9fcf7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_032fb6899c6c07ef5e8f47ab6cb9fcf7.addTo(map_a25558255bc853fed530d96063827584);
#
#
#             var marker_d78ac11d4f451218446b675d536f14fe = L.marker(
#                 [1.294284039296162, 103.7697100325711],
#                 {}
#             ).addTo(map_a25558255bc853fed530d96063827584);
#
#
#             var icon_05b9dae481671977b61751cd0074c562 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d78ac11d4f451218446b675d536f14fe.setIcon(icon_05b9dae481671977b61751cd0074c562);
#
#
#         var popup_abb098f30314d2f21c614f4a44142a7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a6908e5c9bddfea9a4cccbadef299a6 = $(`&lt;div id=&quot;html_3a6908e5c9bddfea9a4cccbadef299a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KR Bus Terminal&lt;/div&gt;`)[0];
#                 popup_abb098f30314d2f21c614f4a44142a7d.setContent(html_3a6908e5c9bddfea9a4cccbadef299a6);
#
#
#
#         marker_d78ac11d4f451218446b675d536f14fe.bindPopup(popup_abb098f30314d2f21c614f4a44142a7d)
#         ;
#
#
#
#
#             var marker_2a494e359fe480d02fa32129b889239f = L.marker(
#                 [1.297233750488144, 103.77269729320729],
#                 {}
#             ).addTo(map_a25558255bc853fed530d96063827584);
#
#
#             var icon_e544e910ddc13b1c1170cb63ef8ca6e6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2a494e359fe480d02fa32129b889239f.setIcon(icon_e544e910ddc13b1c1170cb63ef8ca6e6);
#
#
#         var popup_0eb9eb7d73fbdc923e4f5be34e6009f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a87862286261958fcd70cac047da4f5f = $(`&lt;div id=&quot;html_a87862286261958fcd70cac047da4f5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;IT&lt;/div&gt;`)[0];
#                 popup_0eb9eb7d73fbdc923e4f5be34e6009f1.setContent(html_a87862286261958fcd70cac047da4f5f);
#
#
#
#         marker_2a494e359fe480d02fa32129b889239f.bindPopup(popup_0eb9eb7d73fbdc923e4f5be34e6009f1)
#         ;
#
#
#
#
#             var marker_0af85c2c9ddf3cb6d9171805130eb571 = L.marker(
#                 [1.2989725099505092, 103.77417867705664],
#                 {}
#             ).addTo(map_a25558255bc853fed530d96063827584);
#
#
#             var icon_03c334fc0ff877187a57059ce18837fe = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0af85c2c9ddf3cb6d9171805130eb571.setIcon(icon_03c334fc0ff877187a57059ce18837fe);
#
#
#         var popup_0dc5131159a8bcaf012bd3efa666af83 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_425ade16b583e5a3ca0812cd6f40e8b2 = $(`&lt;div id=&quot;html_425ade16b583e5a3ca0812cd6f40e8b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Opp YIH&lt;/div&gt;`)[0];
#                 popup_0dc5131159a8bcaf012bd3efa666af83.setContent(html_425ade16b583e5a3ca0812cd6f40e8b2);
#
#
#
#         marker_0af85c2c9ddf3cb6d9171805130eb571.bindPopup(popup_0dc5131159a8bcaf012bd3efa666af83)
#         ;
#
#
#
#
#             var marker_2f463e9bc236b66da957d00795249875 = L.marker(
#                 [1.3010811364904713, 103.77369406623278],
#                 {}
#             ).addTo(map_a25558255bc853fed530d96063827584);
#
#
#             var icon_354dd51d38c97d921291ef998e4a3104 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;

# %% [markdown]
# ### Getting accurate route data from Mapbox API

# %%
museum_to_utown_url = 'https://api.mapbox.com/directions/v5/mapbox/driving/103.773474%2C1.301166%3B103.774422%2C1.303533?alternatives=false&geometries=geojson&language=en&overview=full&steps=true&access_token=pk.eyJ1IjoiZ3VvaG9uZ3lpMTExIiwiYSI6ImNtMng0OHc4cTAwenMybG9iczg4cjBoNjcifQ.tc6o1kU_mTemKQhbVy5mNA'
response = requests.get(museum_to_utown_url)
museum_to_utown = response.json()

utown_to_yih_url = 'https://api.mapbox.com/directions/v5/mapbox/driving/103.774422%2C1.303533%3B103.774308%2C1.298869?alternatives=false&geometries=geojson&language=en&overview=full&steps=true&access_token=pk.eyJ1IjoiZ3VvaG9uZ3lpMTExIiwiYSI6ImNtMng0OHc4cTAwenMybG9iczg4cjBoNjcifQ.tc6o1kU_mTemKQhbVy5mNA'
yih_response = requests.get(utown_to_yih_url)
utown_to_yih = yih_response.json()

utown_to_uhc_url = 'https://api.mapbox.com/directions/v5/mapbox/driving/103.774422%2C1.303533%3B103.776055%2C1.298898?alternatives=false&geometries=geojson&language=en&overview=full&steps=true&access_token=pk.eyJ1IjoiZ3VvaG9uZ3lpMTExIiwiYSI6ImNtMng0OHc4cTAwenMybG9iczg4cjBoNjcifQ.tc6o1kU_mTemKQhbVy5mNA'
uhc_response = requests.get(utown_to_uhc_url)
utown_to_uhc = uhc_response.json()

# %% [markdown]
# ### D1 route

# %% [markdown]
# #### Operating hours
# | Term | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0720 | 2300 |
# | Sun/PH | 0900 | 2300 |

# %% [markdown]
# | Vacation | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0720 | 2300 |
# | Sun/PH | 0900 | 2300 |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday |  | Sun/PH |  |
# | --- | --- | --- | --- | --- | --- |
# | 0715 - 0800 | 10-12 min | 0720 - 1930 | 15 min | 0900 - 2300 | 30 min |
# | 0801 - 1930 | 6-8 min | 1931 - 2300 | 30 min | | |
# | 1931 - 2130 | 11-13 min | | | | |
# | 2131 - 2300 | 15 min | | | | |

# %%
D1_bus = ['COM3', 'Opp HSSML', 'Opp NUSS', 'Ventus', 'IT', 'Opp YIH', 'Museum', 'UTown', 'YIH', 'CLB', 'LT13', 'AS5', 'BIZ2', 'COM3']

D1_stops = bus_stops[bus_stops['Bus Stop'].isin(D1_bus)]
D1_route_df = pd.DataFrame({'Bus Stop': D1_bus})
D1_route_df['route_index'] = D1_route_df.index

D1 = D1_route_df.merge(D1_stops, on='Bus Stop', how='left')
D1.loc[D1['route_index']==0, 'color'] = 'red'
D1.loc[D1['route_index']!=0, 'color'] = 'blue'
D1.loc[D1['route_index']==D1.shape[0]-1, 'color'] = 'red'
D1.drop(columns='route_index', inplace=True)


map = folium.Map(location = [1.2993920113270834, 103.77841451795645], zoom_start = 16)
for i in range(len(D1)):
    folium.Marker(location=[D1.iloc[i, 1], D1.iloc[i, 2]], icon=folium.Icon(color=D1.iloc[i, 3]), popup=D1.iloc[i, 0]).add_to(map)

# COM3 to Museum
dir_coord_museum = [(D1.iloc[i,2], D1.iloc[i,1]) for i in range(7)]
route = client.directions(coordinates=dir_coord_museum, profile='driving-car', format='geojson')
route_coords_museum = [list(reversed(coord)) for coord in route['features'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords_museum,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

# Museum to UTown
route_coords = [list(reversed(coord)) for coord in museum_to_utown['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

# UTown to YIH
route_coords = [list(reversed(coord)) for coord in utown_to_yih['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

# YIH to COM3
dir_coord_rem = [(D1.iloc[i,2], D1.iloc[i,1]) for i in range(8, len(D1))]
route = client.directions(coordinates=dir_coord_rem, profile='driving-car', format='geojson')
route_coords_rem = [list(reversed(coord)) for coord in route['features'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords_rem,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)


map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15b1a4296fddc815c8134ece3efac839 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15b1a4296fddc815c8134ece3efac839&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15b1a4296fddc815c8134ece3efac839 = L.map(
#                 &quot;map_15b1a4296fddc815c8134ece3efac839&quot;,
#                 {
#                     center: [1.2993920113270834, 103.77841451795645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e0446922f6e29cd566d91c9ddc65dec = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1e0446922f6e29cd566d91c9ddc65dec.addTo(map_15b1a4296fddc815c8134ece3efac839);
#
#
#             var marker_7ede9122463b4d18bf57c8789f2ab2ca = L.marker(
#                 [1.2949617429822875, 103.77496526464915],
#                 {}
#             ).addTo(map_15b1a4296fddc815c8134ece3efac839);
#
#
#             var icon_86330dbc1ed2382bc5ce702b256dc514 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7ede9122463b4d18bf57c8789f2ab2ca.setIcon(icon_86330dbc1ed2382bc5ce702b256dc514);
#
#
#         var popup_936880c4fafff3b0fc0e4a18c7893719 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_70bd641a94d792fc41e45573bec176c9 = $(`&lt;div id=&quot;html_70bd641a94d792fc41e45573bec176c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;COM3&lt;/div&gt;`)[0];
#                 popup_936880c4fafff3b0fc0e4a18c7893719.setContent(html_70bd641a94d792fc41e45573bec176c9);
#
#
#
#         marker_7ede9122463b4d18bf57c8789f2ab2ca.bindPopup(popup_936880c4fafff3b0fc0e4a18c7893719)
#         ;
#
#
#
#
#             var marker_646ed206c867452464f9380e7f160b9f = L.marker(
#                 [1.2929633209890283, 103.77511784531816],
#                 {}
#             ).addTo(map_15b1a4296fddc815c8134ece3efac839);
#
#
#             var icon_098d2d2b938a689d5a4f961bb635707f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_646ed206c867452464f9380e7f160b9f.setIcon(icon_098d2d2b938a689d5a4f961bb635707f);
#
#
#         var popup_ed3ddbf542a960f64a34fd2f508db595 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_282b56c573a084e3d25243a3c60805cf = $(`&lt;div id=&quot;html_282b56c573a084e3d25243a3c60805cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Opp HSSML&lt;/div&gt;`)[0];
#                 popup_ed3ddbf542a960f64a34fd2f508db595.setContent(html_282b56c573a084e3d25243a3c60805cf);
#
#
#
#         marker_646ed206c867452464f9380e7f160b9f.bindPopup(popup_ed3ddbf542a960f64a34fd2f508db595)
#         ;
#
#
#
#
#             var marker_5ecf3e73666ac87b477dbece5d321c42 = L.marker(
#                 [1.293395191541194, 103.77190542434612],
#                 {}
#             ).addTo(map_15b1a4296fddc815c8134ece3efac839);
#
#
#             var icon_286ccab227d2236c7e9552cb80758186 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5ecf3e73666ac87b477dbece5d321c42.setIcon(icon_286ccab227d2236c7e9552cb80758186);
#
#
#         var popup_72b88af9480ca9a073ee89dad0f79ef8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17d5ff62ffccd06474259ff1accf3494 = $(`&lt;div id=&quot;html_17d5ff62ffccd06474259ff1accf3494&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Opp NUSS&lt;/div&gt;`)[0];
#                 popup_72b88af9480ca9a073ee89dad0f79ef8.setContent(html_17d5ff62ffccd06474259ff1accf3494);
#
#
#
#         marker_5ecf3e73666ac87b477dbece5d321c42.bindPopup(popup_72b88af9480ca9a073ee89dad0f79ef8)
#         ;
#
#
#
#
#             var marker_54a74c1e5649a9c6a70a740eeec6c305 = L.marker(
#                 [1.2953354050928836, 103.77053080902668],
#                 {}
#             ).addTo(map_15b1a4296fddc815c8134ece3efac839);
#
#
#             var icon_7714d987f59d44f507dadc9da266874c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:

# %% [markdown]
# ### D2 route

# %% [markdown]
# #### Operating hours
# | Term | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0720 | 2300 |
# | Sun/PH | 0905 | 2300 |

# %% [markdown]
# | Vacation | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0715 | 2300 |
# | Saturday | 0720 | 2300 |
# | Sun/PH | 0905 | 2300 |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday |  | Sun/PH |  |
# | --- | --- | --- | --- | --- | --- |
# | 0715 - 1000 | 5-7 min | 0720 - 1930 | 15 min | 0900 - 2300 | 30 min |
# | 1001 - 1115 | 9-11 min | 1931 - 2300 | 30 min | | |
# | 1116 - 1400 | 5-7 min | | | | |
# | 1401 - 1715 | 7-9 min | | | | |
# | 1716 - 1930 | 5-7 min | | | | |
# | 1931 - 2130 | 10-12 min | | | | |
# | 2131 - 2300 | 15 min | | | | |

# %%
D2_bus = ['COM3', 'Opp TCOMS', 'PGP Terminal', 'KR MRT', 'LT27', 'University Hall', 'Opp UHC', 'Museum', 
          'UTown', 'UHC', 'Opp University Hall', 'S17', 'Opp KR MRT', 'PGP Foyer', 'TCOMS', 'COM3']

D2_stops = bus_stops[bus_stops['Bus Stop'].isin(D2_bus)]
D2_route_df = pd.DataFrame({'Bus Stop': D2_bus})
D2_route_df['route_index'] = D2_route_df.index

D2 = D2_route_df.merge(D2_stops, on='Bus Stop', how='left')
D2.loc[D2['route_index']==0, 'color'] = 'red'
D2.loc[D2['route_index']!=0, 'color'] = 'blue'
D2.loc[D2['route_index']==D2.shape[0]-1, 'color'] = 'red'
D2.drop(columns='route_index', inplace=True)


map = folium.Map(location = [1.2993920113270834, 103.77841451795645], zoom_start = 16)
for i in range(len(D2)):
    folium.Marker(location=[D2.iloc[i, 1], D2.iloc[i, 2]], icon=folium.Icon(color=D2.iloc[i, 3]), popup=D2.iloc[i, 0]).add_to(map)

# # split routes into 3 segments so that the entire route is accurate

# COM3 to Museum
dir_coord_museum = [(D2.iloc[i,2], D2.iloc[i,1]) for i in range(8)]
route = client.directions(coordinates=dir_coord_museum, profile='driving-car', format='geojson')
route_coords_museum = [list(reversed(coord)) for coord in route['features'][0]['geometry']['coordinates']]

folium.PolyLine(locations=route_coords_museum,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

# Museum to UTown
route_coords = [list(reversed(coord)) for coord in museum_to_utown['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

# UTown to UHC
route_coords = [list(reversed(coord)) for coord in utown_to_uhc['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

# UHC to COM3
dir_coord_rem = [(D2.iloc[i,2], D2.iloc[i,1]) for i in range(9, len(D2))]
route = client.directions(coordinates=dir_coord_rem, profile='driving-car', format='geojson')
route_coords_rem = [list(reversed(coord)) for coord in route['features'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords_rem,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0563eee4e494348b55a03af72705b628 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0563eee4e494348b55a03af72705b628&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0563eee4e494348b55a03af72705b628 = L.map(
#                 &quot;map_0563eee4e494348b55a03af72705b628&quot;,
#                 {
#                     center: [1.2993920113270834, 103.77841451795645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12acd08d61df12c805c969a864da84d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_12acd08d61df12c805c969a864da84d8.addTo(map_0563eee4e494348b55a03af72705b628);
#
#
#             var marker_1e642ae767d9d67e6089f4fcd6c86d3b = L.marker(
#                 [1.2949617429822875, 103.77496526464915],
#                 {}
#             ).addTo(map_0563eee4e494348b55a03af72705b628);
#
#
#             var icon_89f5484180af011c9acb882fffaff7c5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1e642ae767d9d67e6089f4fcd6c86d3b.setIcon(icon_89f5484180af011c9acb882fffaff7c5);
#
#
#         var popup_eb1b69cf509bf0049c2d628dbe81bb56 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f6afbb03feb7baf69ca3b0abea52bde0 = $(`&lt;div id=&quot;html_f6afbb03feb7baf69ca3b0abea52bde0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;COM3&lt;/div&gt;`)[0];
#                 popup_eb1b69cf509bf0049c2d628dbe81bb56.setContent(html_f6afbb03feb7baf69ca3b0abea52bde0);
#
#
#
#         marker_1e642ae767d9d67e6089f4fcd6c86d3b.bindPopup(popup_eb1b69cf509bf0049c2d628dbe81bb56)
#         ;
#
#
#
#
#             var marker_cbbced5523a04e1901e7c27e83e48b70 = L.marker(
#                 [1.2937113340845738, 103.77700719838774],
#                 {}
#             ).addTo(map_0563eee4e494348b55a03af72705b628);
#
#
#             var icon_953db09a1d0fbe7f008cbff990f25367 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cbbced5523a04e1901e7c27e83e48b70.setIcon(icon_953db09a1d0fbe7f008cbff990f25367);
#
#
#         var popup_49ffd0fc438d4cb1dc48314fdc44aa66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4310b9a05f83288c0a277506e2f2aa81 = $(`&lt;div id=&quot;html_4310b9a05f83288c0a277506e2f2aa81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Opp TCOMS&lt;/div&gt;`)[0];
#                 popup_49ffd0fc438d4cb1dc48314fdc44aa66.setContent(html_4310b9a05f83288c0a277506e2f2aa81);
#
#
#
#         marker_cbbced5523a04e1901e7c27e83e48b70.bindPopup(popup_49ffd0fc438d4cb1dc48314fdc44aa66)
#         ;
#
#
#
#
#             var marker_f4490237c06f5b92eaeebd058ddee987 = L.marker(
#                 [1.2918452689707198, 103.78043600861773],
#                 {}
#             ).addTo(map_0563eee4e494348b55a03af72705b628);
#
#
#             var icon_2492cd02f62cff8907956173af6f5d95 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f4490237c06f5b92eaeebd058ddee987.setIcon(icon_2492cd02f62cff8907956173af6f5d95);
#
#
#         var popup_211ecef687cee8e4d54fcd8bad7736ee = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4809e596a4273840c3dc9c4e8105698f = $(`&lt;div id=&quot;html_4809e596a4273840c3dc9c4e8105698f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PGP Terminal&lt;/div&gt;`)[0];
#                 popup_211ecef687cee8e4d54fcd8bad7736ee.setContent(html_4809e596a4273840c3dc9c4e8105698f);
#
#
#
#         marker_f4490237c06f5b92eaeebd058ddee987.bindPopup(popup_211ecef687cee8e4d54fcd8bad7736ee)
#         ;
#
#
#
#
#             var marker_cae48c823be89f4aad0f794af5597425 = L.marker(
#                 [1.2948032131296237, 103.7843978019587],
#                 {}
#             ).addTo(map_0563eee4e494348b55a03af72705b628);
#
#
#             var icon_b2b129be8ff12a030d22a1e30cb5588a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&qu

# %% [markdown]
# ### BTC route

# %% [markdown]
# #### Operating hours
# | Term | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0730 | 2140 |
# | Saturday | No service |
# | Sun/PH | No service |

# %% [markdown]
# | Vacation | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0730 | 1940 |
# | Saturday | No service |
# | Sun/PH | No service |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday |  Sun/PH |
# | --- | --- | --- | --- |
# | 0730 - 1000 | 30 min | No service |  No service |
# | 1001 - 1110 | 35 min |
# | 1111 - 1410 | 30 min |
# | 1401 - 1710 | 45 min |
# | 1711 - 1940 | 30 min |
# | 1941 - 2110 | 45 min |
# | 2111 - 2140 | 30 min |

# %%
btc_url = 'https://api.mapbox.com/directions/v5/mapbox/driving/103.817832%2C1.319848%3B103.818893%2C1.320928%3B103.815903%2C1.32268%3B103.784429%2C1.294841%3B103.780988%2C1.297413%3B103.778766%2C1.297204%3B103.775656%2C1.29881%3B103.774434%2C1.303535%3B103.772749%2C1.301005%3B103.769636%2C1.301896%3B103.769058%2C1.302245%3B103.773469%2C1.301136%3B103.774308%2C1.298863%3B103.772194%2C1.296321%3B103.770581%2C1.294841%3B103.771738%2C1.293506%3B103.775121%2C1.29325%3B103.780403%2C1.291822%3B103.816278%2C1.323278%3B103.81827%2C1.319337?alternatives=false&geometries=geojson&language=en&overview=full&steps=true&access_token=pk.eyJ1IjoiZ3VvaG9uZ3lpMTExIiwiYSI6ImNtMng0OHc4cTAwenMybG9iczg4cjBoNjcifQ.tc6o1kU_mTemKQhbVy5mNA'
response = requests.get(btc_url)
btc_route = response.json()

# %%
BTC_bus = ['Oei Tiong Ham Building (BTC)', 'Botanic Gardens MRT (BTC)', 'KR MRT', 'LT27', 'University Hall', 'Opp UHC', 
           'UTown', 'Raffles Hall', 'Kent Vale', 'Museum', 'YIH', 'CLB', 'LT13', 'AS5', 'BIZ2', 'PGP Terminal', 'College Green (BTC)', 
           'Oei Tiong Ham Building (BTC)']

BTC_stops = bus_stops[bus_stops['Bus Stop'].isin(BTC_bus)]
BTC_route_df = pd.DataFrame({'Bus Stop': BTC_bus})
BTC_route_df['route_index'] = BTC_route_df.index

BTC = BTC_route_df.merge(BTC_stops, on='Bus Stop', how='left')
BTC.loc[BTC['route_index']==0, 'color'] = 'red'
BTC.loc[BTC['route_index']!=0, 'color'] = 'blue'
BTC.loc[BTC['route_index']==BTC.shape[0]-1, 'color'] = 'red'
BTC.drop(columns='route_index', inplace=True)

map = folium.Map(location = [1.2993920113270834, 103.77841451795645], zoom_start = 14)
for i in range(len(BTC)):
    folium.Marker(location=[BTC.iloc[i, 1], BTC.iloc[i, 2]], icon=folium.Icon(color=BTC.iloc[i, 3]), popup=BTC.iloc[i, 0]).add_to(map)

route_coords = [list(reversed(coord)) for coord in btc_route['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78756774f554048e41b67a9b96794fa2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78756774f554048e41b67a9b96794fa2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78756774f554048e41b67a9b96794fa2 = L.map(
#                 &quot;map_78756774f554048e41b67a9b96794fa2&quot;,
#                 {
#                     center: [1.2993920113270834, 103.77841451795645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73f0c276c17512edeabbd474483b152e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_73f0c276c17512edeabbd474483b152e.addTo(map_78756774f554048e41b67a9b96794fa2);
#
#
#             var marker_510291b41c92d7e416112498098bd6c5 = L.marker(
#                 [1.3198303112461514, 103.81775937050531],
#                 {}
#             ).addTo(map_78756774f554048e41b67a9b96794fa2);
#
#
#             var icon_07c2a957806f0d9eecd0306e8066a87c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_510291b41c92d7e416112498098bd6c5.setIcon(icon_07c2a957806f0d9eecd0306e8066a87c);
#
#
#         var popup_fdd354815f382a154908fef12daa2abd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4481ffb729433131d35b64bf8b9d202 = $(`&lt;div id=&quot;html_e4481ffb729433131d35b64bf8b9d202&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Oei Tiong Ham Building (BTC)&lt;/div&gt;`)[0];
#                 popup_fdd354815f382a154908fef12daa2abd.setContent(html_e4481ffb729433131d35b64bf8b9d202);
#
#
#
#         marker_510291b41c92d7e416112498098bd6c5.bindPopup(popup_fdd354815f382a154908fef12daa2abd)
#         ;
#
#
#
#
#             var marker_6228900ebf1e744cfd9505837adc80ec = L.marker(
#                 [1.3227333266951262, 103.8151647850129],
#                 {}
#             ).addTo(map_78756774f554048e41b67a9b96794fa2);
#
#
#             var icon_03fff7ae9f9714e29f1a84242386bef8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6228900ebf1e744cfd9505837adc80ec.setIcon(icon_03fff7ae9f9714e29f1a84242386bef8);
#
#
#         var popup_a3226ffc1330e0133707e2dd20c3c1c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2135fbef4acf128cb35a72e771ea6b28 = $(`&lt;div id=&quot;html_2135fbef4acf128cb35a72e771ea6b28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Botanic Gardens MRT (BTC)&lt;/div&gt;`)[0];
#                 popup_a3226ffc1330e0133707e2dd20c3c1c6.setContent(html_2135fbef4acf128cb35a72e771ea6b28);
#
#
#
#         marker_6228900ebf1e744cfd9505837adc80ec.bindPopup(popup_a3226ffc1330e0133707e2dd20c3c1c6)
#         ;
#
#
#
#
#             var marker_7c38c78815f8d7d061349bd5323d2d43 = L.marker(
#                 [1.2948032131296237, 103.7843978019587],
#                 {}
#             ).addTo(map_78756774f554048e41b67a9b96794fa2);
#
#
#             var icon_26c8f9f5c4c32a0a7d1cfaa91f664bcf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7c38c78815f8d7d061349bd5323d2d43.setIcon(icon_26c8f9f5c4c32a0a7d1cfaa91f664bcf);
#
#
#         var popup_96179f1d1e50b677d19067577a578127 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_963ac417e584a03964d7c80489172899 = $(`&lt;div id=&quot;html_963ac417e584a03964d7c80489172899&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KR MRT&lt;/div&gt;`)[0];
#                 popup_96179f1d1e50b677d19067577a578127.setContent(html_963ac417e584a03964d7c80489172899);
#
#
#
#         marker_7c38c78815f8d7d061349bd5323d2d43.bindPopup(popup_96179f1d1e50b677d19067577a578127)
#         ;
#
#
#
#
#             var marker_d24c7bafe66813d799bbe1ea2743a1a3 = L.marker(
#                 [1.297352137914635, 103.78095164513468],
#                 {}
#             ).addTo(map_78756774f554048e41b67a9b96794fa2);
#
#
#             var icon_189b694008b8d00d0a230e7cfce6c731 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;

# %% [markdown]
# ### E route

# %% [markdown]
# #### Operating hours
# | Term | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0800 | 1600 |
# | Saturday | No service |
# | Sun/PH | No service |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday | Sun/PH |
# | --- | --- | --- | --- |
# | 0800 - 1000 | 15 min | No service | No service |
# | 1115 - 1400 | 15 min |
# | 1515 - 1600 | 15 min |

# %%
E_url = 'https://api.mapbox.com/directions/v5/mapbox/driving/103.774437%2C1.303529%3B103.772744%2C1.301%3B103.769629%2C1.301897%3B103.769053%2C1.302199%3B103.770144%2C1.300623%3B103.769865%2C1.297757%3B103.77271%2C1.297189%3B103.774132%2C1.298847%3B103.774415%2C1.303511?alternatives=false&geometries=geojson&language=en&overview=full&steps=true&access_token=pk.eyJ1IjoiZ3VvaG9uZ3lpMTExIiwiYSI6ImNtMng0OHc4cTAwenMybG9iczg4cjBoNjcifQ.tc6o1kU_mTemKQhbVy5mNA'
responses = requests.get(E_url)
E_route = responses.json()

# %%
E_bus = ['UTown', 'Raffles Hall', 'Kent Vale', 'EA', 'SDE3', 'IT', 'Opp YIH', 'UTown']

E_stops = bus_stops[bus_stops['Bus Stop'].isin(E_bus)]
E_route_df = pd.DataFrame({'Bus Stop': E_bus})
E_route_df['route_index'] = E_route_df.index

E = E_route_df.merge(E_stops, on='Bus Stop', how='left')
E.loc[E['route_index']==0, 'color'] = 'red'
E.loc[E['route_index']!=0, 'color'] = 'blue'
E.loc[E['route_index']==E.shape[0]-1, 'color'] = 'red'
E.drop(columns='route_index', inplace=True)


map = folium.Map(location = [1.3002841404515253, 103.77231795009253], zoom_start = 17)
for i in range(len(E)):
    folium.Marker(location=[E.iloc[i, 1], E.iloc[i, 2]], icon=folium.Icon(color=E.iloc[i, 3]), popup=E.iloc[i, 0]).add_to(map)


route_coords = [list(reversed(coord)) for coord in E_route['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d71b1fd89605083cb43a75cb564fbbcb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d71b1fd89605083cb43a75cb564fbbcb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d71b1fd89605083cb43a75cb564fbbcb = L.map(
#                 &quot;map_d71b1fd89605083cb43a75cb564fbbcb&quot;,
#                 {
#                     center: [1.3002841404515253, 103.77231795009253],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 17,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0030b8508f67d9786e9dd19f862602d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b0030b8508f67d9786e9dd19f862602d.addTo(map_d71b1fd89605083cb43a75cb564fbbcb);
#
#
#             var marker_37a2b65bea93303b65a9be144db7cac8 = L.marker(
#                 [1.3035546593332374, 103.77441438310554],
#                 {}
#             ).addTo(map_d71b1fd89605083cb43a75cb564fbbcb);
#
#
#             var icon_64f9f171a168852a18ab352b8868fd49 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_37a2b65bea93303b65a9be144db7cac8.setIcon(icon_64f9f171a168852a18ab352b8868fd49);
#
#
#         var popup_3f874ec77e05098d027414b87e6326be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_557b2ae972793bb8f5b2ebe40fd851e1 = $(`&lt;div id=&quot;html_557b2ae972793bb8f5b2ebe40fd851e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTown&lt;/div&gt;`)[0];
#                 popup_3f874ec77e05098d027414b87e6326be.setContent(html_557b2ae972793bb8f5b2ebe40fd851e1);
#
#
#
#         marker_37a2b65bea93303b65a9be144db7cac8.bindPopup(popup_3f874ec77e05098d027414b87e6326be)
#         ;
#
#
#
#
#             var marker_bdfbcbcc366fd7b4d26d6a4b48139f8a = L.marker(
#                 [1.300977165579121, 103.77270175961483],
#                 {}
#             ).addTo(map_d71b1fd89605083cb43a75cb564fbbcb);
#
#
#             var icon_b8ec4002fc149b858262c28082a320c8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bdfbcbcc366fd7b4d26d6a4b48139f8a.setIcon(icon_b8ec4002fc149b858262c28082a320c8);
#
#
#         var popup_7c52b421517a4ef136f8e5c6b99a010e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f9bddacb7626795a3d81dcbe9bcce3e8 = $(`&lt;div id=&quot;html_f9bddacb7626795a3d81dcbe9bcce3e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Raffles Hall&lt;/div&gt;`)[0];
#                 popup_7c52b421517a4ef136f8e5c6b99a010e.setContent(html_f9bddacb7626795a3d81dcbe9bcce3e8);
#
#
#
#         marker_bdfbcbcc366fd7b4d26d6a4b48139f8a.bindPopup(popup_7c52b421517a4ef136f8e5c6b99a010e)
#         ;
#
#
#
#
#             var marker_6326b2110069f25e1aa4c8758f002143 = L.marker(
#                 [1.3019605740478033, 103.7694762443471],
#                 {}
#             ).addTo(map_d71b1fd89605083cb43a75cb564fbbcb);
#
#
#             var icon_784429d078583d0f823b2f2ad42af000 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6326b2110069f25e1aa4c8758f002143.setIcon(icon_784429d078583d0f823b2f2ad42af000);
#
#
#         var popup_8062032b6ca0839aa8164e0b34be8aa1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a5b10ec9c7e835851b0b65f7401e773 = $(`&lt;div id=&quot;html_8a5b10ec9c7e835851b0b65f7401e773&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kent Vale&lt;/div&gt;`)[0];
#                 popup_8062032b6ca0839aa8164e0b34be8aa1.setContent(html_8a5b10ec9c7e835851b0b65f7401e773);
#
#
#
#         marker_6326b2110069f25e1aa4c8758f002143.bindPopup(popup_8062032b6ca0839aa8164e0b34be8aa1)
#         ;
#
#
#
#
#             var marker_e5e9992d6b3ba01d8590bc98acd079cd = L.marker(
#                 [1.3006008936256923, 103.77017267417776],
#                 {}
#             ).addTo(map_d71b1fd89605083cb43a75cb564fbbcb);
#
#
#             var icon_4c5bc58a66c0d152875dc1033f2dfe8d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&qu

# %% [markdown]
# ### K route

# %% [markdown]
# #### Operating hours
# | Term/Vacation | First Bus | Last Bus |
# | --- | --- | --- |
# | Weekday | 0700 | 2300 |
# | Saturday | 0700 | 1930 |
# | Sun/PH | No service |

# %% [markdown]
# #### Frequency
# | Weekday |  | Saturday | | Sun/PH |
# | --- | --- | --- | --- | --- |
# | 0700 - 2300 | 40 min | 0700 - 1930 | 40 min | No service |

# %%
K_url = 'https://api.mapbox.com/directions/v5/mapbox/driving/103.78039%2C1.2918%3B103.784424%2C1.294834%3B103.780996%2C1.297405%3B103.778771%2C1.297191%3B103.775658%2C1.298817%3B103.774306%2C1.298857%3B103.772199%2C1.296316%3B103.769637%2C1.297888%3B103.769957%2C1.300739%3B103.769629%2C1.301901%3B103.769015%2C1.302229%3B103.773468%2C1.301142%3B103.77606%2C1.298901%3B103.778076%2C1.297504%3B103.780704%2C1.297515%3B103.784574%2C1.294956%3B103.781073%2C1.290993?alternatives=false&geometries=geojson&language=en&overview=full&steps=true&access_token=pk.eyJ1IjoiZ3VvaG9uZ3lpMTExIiwiYSI6ImNtMng0OHc4cTAwenMybG9iczg4cjBoNjcifQ.tc6o1kU_mTemKQhbVy5mNA'
responses = requests.get(K_url)
K_route = responses.json()

# %%
K_bus = ['PGP Terminal', 'KR MRT', 'LT27', 'University Hall', 'Opp UHC', 'YIH', 'CLB', 'Opp SDE3', 'The Japanese Primary School', 
         'Kent Vale', 'Museum', 'UHC', 'Opp University Hall', 'S17', 'Opp KR MRT', 'PGP Foyer']

K_stops = bus_stops[bus_stops['Bus Stop'].isin(K_bus)]
K_route_df = pd.DataFrame({'Bus Stop': K_bus})
K_route_df['route_index'] = K_route_df.index

K = K_route_df.merge(K_stops, on='Bus Stop', how='left')
K.loc[K['route_index']==0, 'color'] = 'red'
K.loc[K['route_index']!=0, 'color'] = 'blue'
K.loc[K['route_index']==K.shape[0]-1, 'color'] = 'red'
K.drop(columns='route_index', inplace=True)

map = folium.Map(location = [1.2993920113270834, 103.77841451795645], zoom_start = 16)
for i in range(len(K)):
    folium.Marker(location=[K.iloc[i, 1], K.iloc[i, 2]], icon=folium.Icon(color=K.iloc[i, 3]), popup=K.iloc[i, 0]).add_to(map)

route_coords = [list(reversed(coord)) for coord in K_route['routes'][0]['geometry']['coordinates']]
folium.PolyLine(locations=route_coords,
                color='blue',
                weight=4,
                smooth_factor=0.1).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b03bbb88023fe6678179176c03f65f35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b03bbb88023fe6678179176c03f65f35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b03bbb88023fe6678179176c03f65f35 = L.map(
#                 &quot;map_b03bbb88023fe6678179176c03f65f35&quot;,
#                 {
#                     center: [1.2993920113270834, 103.77841451795645],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6791eb1fe33aaa05e578fbb822dbabba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6791eb1fe33aaa05e578fbb822dbabba.addTo(map_b03bbb88023fe6678179176c03f65f35);
#
#
#             var marker_7480bd46b709d7288243e51faec0d13b = L.marker(
#                 [1.2918452689707198, 103.78043600861773],
#                 {}
#             ).addTo(map_b03bbb88023fe6678179176c03f65f35);
#
#
#             var icon_df2aac2cba98a1a1a508dd9e3d7e0a58 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7480bd46b709d7288243e51faec0d13b.setIcon(icon_df2aac2cba98a1a1a508dd9e3d7e0a58);
#
#
#         var popup_f01273c173476e6a9be773d98cb4195e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_642862ac13d88d37756d0c1ef150f778 = $(`&lt;div id=&quot;html_642862ac13d88d37756d0c1ef150f778&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PGP Terminal&lt;/div&gt;`)[0];
#                 popup_f01273c173476e6a9be773d98cb4195e.setContent(html_642862ac13d88d37756d0c1ef150f778);
#
#
#
#         marker_7480bd46b709d7288243e51faec0d13b.bindPopup(popup_f01273c173476e6a9be773d98cb4195e)
#         ;
#
#
#
#
#             var marker_1d5da8cacebe80035b2a6c8c0d4ecd62 = L.marker(
#                 [1.2948032131296237, 103.7843978019587],
#                 {}
#             ).addTo(map_b03bbb88023fe6678179176c03f65f35);
#
#
#             var icon_0917bf1d4f673c7eec9ce9153cf4e748 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1d5da8cacebe80035b2a6c8c0d4ecd62.setIcon(icon_0917bf1d4f673c7eec9ce9153cf4e748);
#
#
#         var popup_3b7af3913b2dec7dd7e4968c3a32c313 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_298adb2a6f0b74921b66bd10f0732586 = $(`&lt;div id=&quot;html_298adb2a6f0b74921b66bd10f0732586&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KR MRT&lt;/div&gt;`)[0];
#                 popup_3b7af3913b2dec7dd7e4968c3a32c313.setContent(html_298adb2a6f0b74921b66bd10f0732586);
#
#
#
#         marker_1d5da8cacebe80035b2a6c8c0d4ecd62.bindPopup(popup_3b7af3913b2dec7dd7e4968c3a32c313)
#         ;
#
#
#
#
#             var marker_0a7934a49a27cb3718550545c7f9cdaa = L.marker(
#                 [1.297352137914635, 103.78095164513468],
#                 {}
#             ).addTo(map_b03bbb88023fe6678179176c03f65f35);
#
#
#             var icon_ce69015fdb8706d9530dd3d0cd933d45 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0a7934a49a27cb3718550545c7f9cdaa.setIcon(icon_ce69015fdb8706d9530dd3d0cd933d45);
#
#
#         var popup_e42135da19f198a0d7fd69eb4c09434a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_32b7508e938d185dcc93b00d94515c29 = $(`&lt;div id=&quot;html_32b7508e938d185dcc93b00d94515c29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;LT27&lt;/div&gt;`)[0];
#                 popup_e42135da19f198a0d7fd69eb4c09434a.setContent(html_32b7508e938d185dcc93b00d94515c29);
#
#
#
#         marker_0a7934a49a27cb3718550545c7f9cdaa.bindPopup(popup_e42135da19f198a0d7fd69eb4c09434a)
#         ;
#
#
#
#
#             var marker_9a482f91bb98798a3063a755eba59c23 = L.marker(
#                 [1.297130588212707, 103.77879580832035],
#                 {}
#             ).addTo(map_b03bbb88023fe6678179176c03f65f35);
#
#
#             var icon_82d20015288db895bd0a1c3d6e6644fa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;:
